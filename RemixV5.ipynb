# %% [markdown]
# # Introduction
# ## Objectives
# 1. The primary objective of this program is to determine whether the mixed audio can be accurately recreated using the mixing coefficients provided in the song collection of the BandHub dataset. If this is the case, the mixed audio need not be stored and can be recreated as and when required, thereby saving us significant space on the file server.
#
# 2. In a handful of cases, the same mix has two mixing coefficients. One in the settings dictionary, and the other in the audioChannels list, which is within the settings dictionary. Most times these are just approximation errors. However, in some cases the differences are significant. Therefore, the secondary objective is to clarify which of these multiple mixing coefficients is more accurate.
#
# ## Code Organization
# 1. Imports
# 2. Connect to mongoDB client
# 3. Get all collections: Songs, Videos, Tracks, and Posts
# 4. Function definitions
#  * All functions have been elaborated on in the markdown cells above them.
# 5. Main script
#  * This script calls all the functions as and when required to accomplish both objectives.

# %% [markdown]
# ### 1. Imports

# %%
# %autosave 5
# Out:
# Autosaving every 5 seconds

# %%
import pymongo
import pandas as pd
import numpy as np
np.set_printoptions(threshold='nan')
from numpy.linalg import inv
from scipy import signal
from scipy.io import wavfile
import soundfile as sf
import matplotlib.pyplot as plt
# %matplotlib inline
from bson.objectid import ObjectId
import json
import pprint
from pydub import AudioSegment
import urllib
import fnmatch
import os
import requests
import ffmpy
import subprocess
import librosa
import librosa.display
import time
import IPython.display as ipd

# %% [markdown]
# ### 2. Connect to mongoDB client

# %%
client = pymongo.MongoClient('localhost',27017)
#client = pymongo.MongoClient('localhost',32768)
db = client.get_database('b=bandhub')

# %% [markdown]
# ### 3. Get all collections: Songs, Videos, Tracks, and Posts

# %%
songCol = db.get_collection('songsStream')
vidCol = db.get_collection('mergedVideos')
trackCol = db.get_collection('tracksStream')
postCol = db.get_collection('posts')
[songCol.count(), vidCol.count(), trackCol.count(), postCol.count()]
# Out:
# [425706, 198169, 915582, 494867]

# %% [markdown]
# ### 4. Function definitions

# %% [markdown]
# From this dataset, we are only concerned with tracks that have "public" access. This is denoted by the variable "songAccess", which and is set to 1 for public tracks.<br>
# Conversely, many mixes have a lot of unused public tracks. The tracks that actually make the final mix are titled "published" tracks. Information about the published tracks in a mix are available only in the post collection, and so this function queries the post collection to return the relevant documents.<br>
# To summarize, this generator returns the documents in the post collection that have a user-specified number (num_track) of published tracks. For our evaluation purposes, we have restricted num_track to be greater than 2.

# %%
def get_published_tracks(num_track):
    """ This generator function returns all post documents with "num_track" published tracks, where num_track > 2.
    ----------
    Arguments:
        num_track: Number of public, published tracks per mix

    Returns:
        docs: All documents from the post collection that satisfy the aforementioned condition
    """
    
    pub_tracks = postCol.find({'songAccess':{'$exists': True}}, {'participantsInfo':1 ,'songAccess':1, 'objectId':1})
    for docs in pub_tracks:
        if(docs['songAccess'] == 1):
            if(len(docs['participantsInfo']['publishedTracks']) == num_track):
                yield docs

# %% [markdown]
# This function aids in achieving the objective of identifying whether bandhub's mixes can be accurately recreated using the given mixing coefficients. First, it sifts through all the documents returned from the get_published_tracks function. Then, it checks and keeps a track of any mixes that have missing published track information. If all the information is present, the post ID and the song ID of the mix are appended to a list and returned.

# %%
def get_processed_audio_ids(num_track):
    """ This function computes a list of the post IDs & master song IDs of those mixes generated by the
    get_published_tracks function that contain multiple mixing coefficients associated with the same mix.
    ----------
    Arguments:
        num_track: Number of public, published tracks per mix

    Returns:
        pub_songs: A list of tuples containing relevant post & track IDs
    """
    
    pub_docs = [x for x in get_published_tracks(num_track)]
    count_mixes = 500
    #count_mixes = len(pub_docs)
    print("Number of mixes with " + str(num_track) + " published tracks: " + str(count_mixes))
    missing_song_id = []
    missing_pubtrack = []
    index_required = []
    pub_songs = []
    for j in range(count_mixes):
        pub_tracks = []
        post_id = pub_docs[j]['_id']
        song_id = pub_docs[j]['objectId']
        
        song_look_up = songCol.find({'masterSongId' : song_id})
        
        for i in range(num_track):
            pub_tracks.append(pub_docs[j]['participantsInfo']['publishedTracks'][i]['_id'])
                                
        if song_look_up is -1:
            missing_song_id.append(song_id)
            pprint.pprint('Error: SongID not found in Song Collection!')
        else:
            for song_docs in song_look_up:
                count_pub_track = 0
                for i in range(len(pub_tracks)):
                    if(str(pub_tracks[i]) not in song_docs['settings']):
                        missing_pubtrack.append(pub_tracks[i])   
                        break
                    else:
                        count_pub_track+=1
                if count_pub_track == num_track:
                    pub_songs.append((post_id,song_id))

    return pub_songs

# %% [markdown]
# This function aids in achieving the objective of identifying the mixes that contain multiple mixing coefficients, to determine which of those coefficients are better to recreate the mix. First, it sifts through all the documents returned from the get_published_tracks function. Then, it checks and keeps a track of any mixes that have missing published track information. If all the information is present, it then checks for mixes that have multiple volume fields. If such mixes are found, it rounds the track volumes associated with each of its constituent published tracks up to 2 decimal places to circumvent the approximation problem (e.g., volumes 0.987221 and 0.99 should not be considered different). The two volumes of each of these tracks are then compared, and if they are different, the post ID and the song ID of the mix are appended to a list and returned.

# %%
def get_processed_audio_ids_multiple_volumes(num_track):
    """ This function computes a list of the post IDs & master song IDs of those mixes generated by the
    get_published_tracks function that contain multiple mixing coefficients associated with the same mix.
    ----------
    Arguments:
        num_track: Number of public, published tracks per mix

    Returns:
        pub_songs: A list of tuples containing relevant post & track IDs
    """
    
    pub_docs = [x for x in get_published_tracks(num_track)]
    count_mixes = 50
    #count_mixes = len(pub_docs)
    print("Number of mixes with " + str(num_track) + " published tracks: " + str(count_mixes))
    missing_song_id = []
    missing_pubtrack = []
    index_required = []
    pub_songs = []
    for j in range(count_mixes):
        pub_tracks = []
        post_id = pub_docs[j]['_id']
        song_id = pub_docs[j]['objectId']
        
        song_look_up = songCol.find({'masterSongId' : song_id})
        
        for i in range(num_track):
            pub_tracks.append(pub_docs[j]['participantsInfo']['publishedTracks'][i]['_id'])
                                
        if song_look_up is -1:
            missing_song_id.append(song_id)
            pprint.pprint('Error: SongID not found in Song Collection!')
        else:
            for song_docs in song_look_up:
                for i in range(len(pub_tracks)):
                    if(str(pub_tracks[i]) not in song_docs['settings']):
                        missing_pubtrack.append(pub_tracks[i])   
                        break
                    else:
                        if ('volume' in song_docs['settings'][str(pub_tracks[i])]['audioChannels'][0] and 'volume' in song_docs['settings'][str(pub_tracks[i])]):
                            if (round(song_docs['settings'][str(pub_tracks[i])]['audioChannels'][0]['volume'],2) != round(song_docs['settings'][str(pub_tracks[i])]['volume'],2)):
                                index_required.append(j)
                                pub_songs.append((post_id,song_id))
                                break
                            else:
                                continue
                        else:
                            #print('Mixing coefficient missing')
                            break

    return pub_songs

# %% [markdown]
# The file URLs in the dataset are of the following format:<br>
# http://bandhubwebmedia1.blob.core.windows.net/files/520c0d243262aac9f04d4351-520c0d8753294aac9f04d4353.ogg<br>
# We can see that the filename is present in this string after the last separator (/). This function strips the file name from the given file URL and returns it.

# %%
def get_filename(file):
    """ This function strips the filename along with the file extension from the file URL.
    ----------
    Arguments:
        file: file URL

    Returns:
        filepath: file path
    """
    
    filePath = file.split('/')
    return filePath[- 1]

# %% [markdown]
# The mixing coefficients necessary to recreate a mix are the following:
# * pub_t_vol: Track volume in the settings dictionary
# * pub_t_vol_ch: Track volume in the audioChannels list, nestled inside the settings dictionary
# * ogg_paths: File paths of the tracks on the server.
# * start_times: Track start times<br>
# Given a song ID and post ID unique to a mix, this function queries the corresponding collections and extracts the above information for every published track in the mix.<br>
# The track volumes are all rounded to 2 decimal places. The file URL is fetched from the effectsAudioURL field, which provides processed tracks (i.e., tracks with effects and processing). If not found, it is fetched from the fileURL field, which provides the raw track file.<br>
# The start times for each track are queried from the track collection.

# %%
def get_mixing_coeff(num_track, song_id, post_id, proc_status):
    """ This function gathers all mixing coefficients necessary to remix a song using its constituent
    published tracks.
    ----------
    Arguments:
        num_track: Number of public, published tracks per mix
        song_id: Song ID
        post_id: Post ID

    Returns:
        pub_t_vol: Published track volumes from the settings field in the song collection
        pub_t_vol_ch: Published track volumes from the audioChannels field within settings in the song collection
        ogg_paths: Processed (if available) or unprocessed file URLs of each published track
        start_times: Start times of each published track
    """
    
    pub_t_vol = []
    pub_t_vol_ch = []
    ogg_paths = []
    start_times = []
    track_filenames = []
    pub_tracks = []

    song_doc = songCol.find({'masterSongId' : song_id})
    post_doc = postCol.find({'_id' : post_id})
    
    for docs in post_doc:
        for i in range(num_track):
            pub_tracks.append(docs['participantsInfo']['publishedTracks'][i]['_id'])
    
    for docs in song_doc:
        p_count = 0 #Processed track count
        for i in range(len(pub_tracks)):
            if(str(pub_tracks[i]) in docs['settings']):
                pub_t_vol.append(round(docs['settings'][str(pub_tracks[i])]['volume'],2))
                if ('volume' in docs['settings'][str(pub_tracks[i])]['audioChannels'][0]):
                    pub_t_vol_ch.append(round(docs['settings'][str(pub_tracks[i])]['audioChannels'][0]['volume'],2))
                else:
                    pub_t_vol_ch.append(round(docs['settings'][str(pub_tracks[i])]['volume'],2))
            
                gettrack = trackCol.find({'_id' : pub_tracks[i]})
                for tdocs in gettrack:
                    start_times.append(tdocs['startTimeValue'])
                    if('effectsAudioUrl' in docs['settings'][str(pub_tracks[i])]):
                        p_count += 1              
                        ogg_paths.append(docs['settings'][str(pub_tracks[i])]['effectsAudioUrl'])
                        print('Processed audio URL')
                    else:
                        ogg_paths.append(tdocs['audioChannels'][0]['fileUrl'])
                        print('Unprocessed audio URL')
            else:
                print('Missing published track!')
        
        if proc_status is 0 and p_count > 0:
            ogg_paths[:] = []
        
    return pub_t_vol, pub_t_vol_ch, ogg_paths, start_times

# %% [markdown]
# This function changes the default working directory to a user-specified folder in the user's scratch directory.

# %%
def set_path():
    """ This function sets the default download path to a subfolder within the user's scratch folder.
    """

    path = '/scratch/rrs432/tracks'
    os.chdir(path)

# %% [markdown]
# Given the file's path on the server, this function downloads the file (as is) onto the local working directory.

# %%
def download_track(ogg_path):
    """ This function downloads the track using its filepath to the default download folder.
    ----------
    Arguments:
        ogg_path: file path
    """    
    set_path()

    r = requests.get(ogg_path)
    filename = get_filename(ogg_path)
    with open(filename, 'wb') as fd:
        for chunk in r.iter_content(chunk_size=128):
            fd.write(chunk)

# %% [markdown]
# This function clears all previously downloaded songs/tracks in the current working directory.

# %%
def clear_downloads():
    """ This function clears all previously downloaded songs/tracks in default download folder.
    """
    ! rm -rf *.ogg *.wav

# %% [markdown]
# To recreate a mix, we first multiply the track volume (which is normalized between 0 and 1) to the track data and sum these tracks and re-normalize the sum. However, this works only if all tracks start at the same time and are of the same length. Many tracks are of instruments that are not playing throughout the song. These tracks may have non-zero start times and are often much shorter than the song.<br>
# This function zero pads such tracks, both from 0 to its start time (if applicable) as well as at the end, such that all tracks are of identical length, which is the length of the longest track. Moreover, this function also convert all mono tracks to stereo.

# %%
def match_track_lengths(num_track,track_filenames,start_times):
    """ This function matches the track durations by zero padding the shorter tracks as well as converts all
    mono tracks to stereo.
    ----------
    Arguments:
        num_track: Number of public, published tracks per mix
        track_filenames: Filenames of tracks
        start_times: Start times of tracks

    Returns:
        ogg_tracks: Length-matched, downloaded, stereo tracks
        mixsr: Sampling rate of the tracks (Hz) 
    """
    
    ogg_tracks = []
    track_lens = []
    sam_rate = []
    for i in range(num_track):
        track, fs = sf.read('/scratch/rrs432/tracks/'+track_filenames[i])
        sam_rate.append(fs)
        
        #Convert mono to stereo
        if track.ndim is not 2:
            track = np.stack((track, track), axis = 1)
        ogg_tracks.append(track)

    if (min(sam_rate) == max(sam_rate)):
        mixsr = sam_rate[0]
    else:
        mixsr = -1
        pprint.pprint('Warning: Sample rates unequal')
    
    
    for i in range(num_track):
        if start_times[i] is not 0:
            prepad = np.zeros(((start_times[i]-1),2))
            ogg_tracks[i] = np.vstack((prepad, ogg_tracks[i]))
        track_lens.append(len(ogg_tracks[i]))
        
    max_track_len = max(track_lens)
    
    for i in range(num_track):
        postpad = np.zeros(((max_track_len - track_lens[i]),2))
        ogg_tracks[i] = np.vstack((ogg_tracks[i], postpad))
        pprint.pprint(np.shape(ogg_tracks[i]))
    
    return ogg_tracks, mixsr

# %% [markdown]
# This function equates the mix durations by zero padding the shorter mix. Mix durations have to match so that their differences can be computed, which is later use in analysis tools like difference spectrograms and RMSE calculations.

# %%
def match_mix_lengths(mix1,mix2):
    """ This function matches the mix durations by zero padding the shorter mix.
    ----------
    Arguments:
        mix1: mix1
        mix2: mix2

    Returns:
        mix1: Length-matched mix1
        mix2: Length-matched mix2 
    """
    if len(mix1) > len(mix2):
        diff_mix_len = np.zeros(((len(mix1)-len(mix2)),2))
        mix2 = np.vstack((mix2, diff_mix_len))
    else:
        diff_mix_len = np.zeros(((len(mix2)-len(mix1)),2))
        mix1 = np.vstack((mix1, diff_mix_len))
    return mix1, mix2

# %% [markdown]
# This function computes the estimated mix by multiplying the track volumes with their corresponding track data and summing the results.<br>
# **Note:** In this notebook, the term *estimated mix* refers to the mix that we manually compute using the given mixing coefficients. Whereas, *bandhub_mix* refers to the mix provided by Bandhub which is coupled with the mixed video.

# %%
def compute_estimated_mix(num_track, vol, tracks, fs):
    """ This function computes the estimated mix using relevant mixing coefficients.
    ----------
    Arguments:
        num_track: Number of public, published tracks per mix
        vol: Track volume
        tracks: Track files
        fs: Sampling rate (Hz)

    Returns:
        mix_ogg: Estimated mix file
    """    
    mix_ogg = 0
    for i in range(num_track):
        mix_ogg += (vol[i]*np.array(tracks[i]))
    return mix_ogg

# %% [markdown]
# In most cases, the Bandhub mix is not available in the dataset as an audio file. It instead has to be stripped from the mixed video file. This process introduces a slight offset in the audio file (approximately 1024 samples).
# This function computes this offset using numpy's correlation function. The offset amount is determined by finding the time (in samples) at which the peak occurs in the correlation plot. Once accurately determined, this offset is then corrected.<br>
# Then, these corrected files are written out into the current working directory. Since all further analysis is performed using librosa, it is read back in using librosa's load function, which represents the audio files as floating point time series.

# %%
def compute_offset_and_shift(estimated_mix, bandhub_mix, mixsr):
    """ This function corrects the offset introduced into the bandhub mix by the audio stripping process.
    ----------
    Arguments:
        estimated_mix: This is the remix computed using the provided mixing coefficients.
        bandhub_mix: This is the mix provided to us by Bandhub. 

    Returns:
        estimated_mix_spec: The estimated mix as a floating point time series.
        bandhub_mix_spec: The bandhub mix as a floating point time series.
    """    
    flag = 0
    if(len(estimated_mix) < len(bandhub_mix)):
        flag = -1
    estimated_mix, bandhub_mix = match_mix_lengths(estimated_mix, bandhub_mix)
    correlation = np.correlate(bandhub_mix[:mixsr,1], estimated_mix[:mixsr,1], 'full')
    #plt.plot(correlation)
    
    offset = np.argmax(correlation, axis=None)
    offset = (2*mixsr - 1)/2 - offset
    if offset is not 0:
        if flag is -1:
            estimated_mix = np.roll(estimated_mix, -offset)
        else:
            bandhub_mix = np.roll(bandhub_mix, -offset)

    sf.write('estimix.wav', estimated_mix, mixsr)
    sf.write('bandmix.wav', bandhub_mix, mixsr)
    
    estimated_mix_spec, sr = librosa.load('estimix.wav', sr=mixsr)
    bandhub_mix_spec, sr = librosa.load('bandmix.wav', sr=mixsr)
    
    print(np.shape(bandhub_mix_spec))
    print(np.shape(estimated_mix_spec))
    
    return estimated_mix_spec,bandhub_mix_spec

# %% [markdown]
# This function plots the difference spectrograms between bandhub's mix and the estimated mix.<br>
# The input arguments are the return values of librosa.load executed on bandhub's mix and the estimated mix. This information is first converted in the dB scale because we are interested in plotting dB-scaled difference spectrograms. After the conversion, the results are simply subtracted from each other and plotted. This function returns the root mean square error between the two mixes.

# %%
def get_diff_mix_data(estimated_mix_spec,bandhub_mix_spec):
    """ This function computes the difference between bandhub's mix and the estimated mix data.
    ----------
    Arguments:
        estimated_mix_spec: The estimated mix as a floating point time series.
        bandhub_mix_spec: The bandhub mix as a floating point time series. 

    Returns:
        diff_mix_data: The difference between the estimated and bandhub mixes.
    """ 
    bandhub_mix_data = librosa.amplitude_to_db(librosa.stft(bandhub_mix_spec), ref=np.max)
    estimated_mix_data = librosa.amplitude_to_db(librosa.stft(estimated_mix_spec), ref=np.max)
    diff_mix_data = abs(np.subtract(bandhub_mix_data,estimated_mix_data))
    return diff_mix_data

# %%
def plot_diff_spectrogram(diff_mix_data): 
    """ This function plots difference spectograms between bandhub's mix and the estimated mix.
    ----------
    Arguments:
        estimated_mix_spec: The estimated mix as a floating point time series.
        bandhub_mix_spec: The bandhub mix as a floating point time series. 

    Returns:
        None
    """  
    plt.figure(figsize=(12, 3))
    librosa.display.specshow(diff_mix_data, y_axis='linear')
    plt.colorbar(format='%+2.0f dB')
    plt.title('Difference Spectrogram')

# %% [markdown]
# ### 5. Main script

# %% [markdown]
# In this section, the above-defined functions are called in the order required to achieve the following objectives:
#  * Determine if the mixed audio can be recreated using its constituent published tracks (available in the post collection) and the mixing coefficients provided in the song collection (track volumes, start times).
#  * In cases where there are multiple mixing coefficients listed for a mix, we have to determine which of them id better to recreate the mix provided by Bandhub.
#  ***

# %% [markdown]
# Set the current working directory to a user-specified folder in the user's scratch folder and clear all previous downloads.

# %%
set_path()
clear_downloads()

# %% [markdown]
# The bandhub dataset has several mixes, each with a different number of published tracks. The variable 'num_pub_track' specifies the number of published tracks in a mix, and it is used to gather all mixes with a fixed number of published tracks. This variable is titled 'num_track' in the function definitions and is the commonly used argument in the functions.

# %%
num_pub_track = 3

# %% [markdown]
# Here we gather all the mixes that have the fixed number of published tracks (num_pub_track) defined above. They are stored in the variable titled 'proc_id' (which stands for processed ids). 'proc_id' is a list of mixes that have 'num_pub_track' published tracks, and each of these mixes is identified by a tuple comprising its post ID and song ID.

# %%
proc_id = get_processed_audio_ids(num_pub_track)
pprint.pprint(proc_id)
# Out:
# Number of mixes with 3 published tracks: 500
# [(ObjectId('546f098c4e5d9e60267e6345'), ObjectId('53cee44ac08331fa2e000441')),
#  (ObjectId('546f0c924e5d9e60267e638a'), ObjectId('52e5bb5b3a71764a49000032')),
#  (ObjectId('546f0c954e5d9e60267e63a6'), ObjectId('5362bb874cc3911b64000965')),
#  (ObjectId('546f0c944e5d9e60267e6395'), ObjectId('52826cd04d7c33556100000f')),
#  (ObjectId('546f0c994e5d9e60267e63c4'), ObjectId('5233984f42d9a89b0e00000a')),
#  (ObjectId('546f0c994e5d9e60267e63c4'), ObjectId('5233984f42d9a89b0e00000a')),
#  (ObjectId('546f0c9b4e5d9e60267e63cc'), ObjectId('5346e55daadff46b2c000126')),
#  (ObjectId('546f0c9e4e5d9e60267e63dc'), ObjectId('53360ca166e46caa60000001')),
#  (ObjectId('546f5a354e5d9e60267e6e51'), ObjectId('53bb0d0266212bf30b000cae')),
#  (ObjectId('546f5ac24e5d9e60267e711e'), ObjectId('53a2dd3f8261256779000007')),
#  (ObjectId('546f5acc4e5d9e60267e713c'), ObjectId('525c62923fbd5a441c000054')),
#  (ObjectId('546f5ae34e5d9e60267e71b7'), ObjectId('53b603e6fbc043c606000459')),
#  (ObjectId('546f5ae04e5d9e60267e719f'), ObjectId('53d4e51ec56aca4844000013')),
#  (ObjectId('546f5b384e5d9e60267e732d'), ObjectId('53da9d33c52cc54744000397')),
#  (ObjectId('546f5b474e5d9e60267e7363'), ObjectId('53daf93c7b002d975800236e')),
#  (ObjectId('546f5b4f4e5d9e60267e7379'), ObjectId('53db22a27b002d9758003059')),
#  (ObjectId('546f5c4c4e5d9e60267e73dd'), ObjectId('53dc6516aba0a6c5070005f3')),
#  (ObjectId('546f5c5d4e5d9e60267e741e'), ObjectId('53cd705a191b06ff02000330')),
#  (ObjectId('546f5c8a4e5d9e60267e74e9'), ObjectId('53a0c955d7936ed440000064')),
#  (ObjectId('546f5cb64e5d9e60267e7594'), ObjectId('53bd89c62bb762151100266c')),
#  (ObjectId('546fa7f44e5d9e60267e7b82'), ObjectId('53e41a174e550f9e722a8fa6')),
#  (ObjectId('546fa81f4e5d9e60267e7d15'), ObjectId('53cb86f934d25f590f000ad5')),
#  (ObjectId('546fa8224e5d9e60267e7d28'), ObjectId('53e415224e550f9e722a8e1b')),
#  (ObjectId('546fa8284e5d9e60267e7d67'), ObjectId('53e17bbc1529f5f31c0003e9')),
#  (ObjectId('546fa83a4e5d9e60267e7de2'), ObjectId('524774cbbf9d3bda1e000019')),
#  (ObjectId('546fa8434e5d9e60267e7e0e'), ObjectId('53e5cfb0655aff43079d459e')),
#  (ObjectId('546fa8654e5d9e60267e7ea2'), ObjectId('53e6116565c009a3282beedd')),
#  (ObjectId('546fa87d4e5d9e60267e7f17'), ObjectId('53deda4a89ee804c150045fb')),
#  (ObjectId('546fa8874e5d9e60267e7f46'), ObjectId('53e3599b635444d4590005d4')),
#  (ObjectId('546fa8e74e5d9e60267e80cb'), ObjectId('53ef2e1b1077790a28b06af6')),
#  (ObjectId('546fa8fd4e5d9e60267e8132'), ObjectId('53f1796de7ba4f4c19c9c5fe')),
#  (ObjectId('546fa9044e5d9e60267e8154'), ObjectId('53f4a8154e54403e79c65ad1')),
#  (ObjectId('546fa92b4e5d9e60267e81f7'), ObjectId('53ea62ac5887b3a70c185dde')),
#  (ObjectId('546fa93d4e5d9e60267e8249'), ObjectId('53f8dceeecc211cf7ed3d744')),
#  (ObjectId('546fa9484e5d9e60267e827e'), ObjectId('53f9da6818606548039196c1')),
#  (ObjectId('546fa9464e5d9e60267e8275'), ObjectId('53b68334fbc043c6060015c7')),
#  (ObjectId('546fa96a4e5d9e60267e830c'), ObjectId('53fc47788a1fbced64347627')),
#  (ObjectId('546fa9744e5d9e60267e8332'), ObjectId('53fcb3f6ca9d2b7320e1ec5d')),
#  (ObjectId('546fa9754e5d9e60267e8338'), ObjectId('53fcc20d8bbf4c8f2a42cd34')),
#  (ObjectId('546fa9944e5d9e60267e83a0'), ObjectId('53fe1edd4aba344677d96cc8')),
#  (ObjectId('546fa99e4e5d9e60267e83c7'), ObjectId('53fdd6ca5140278640130bc1')),
#  (ObjectId('546fa9ba4e5d9e60267e83e4'), ObjectId('53fdfb3e0f6c2a5a52f36971')),
#  (ObjectId('546fa9f24e5d9e60267e8491'), ObjectId('54011dea46b4c53f6174ec38')),
#  (ObjectId('546faa234e5d9e60267e8548'), ObjectId('5403f28e21715eed7bc3b23b')),
#  (ObjectId('546faa224e5d9e60267e8546'), ObjectId('54035c0a3c77863321d64b26')),
#  (ObjectId('546faa6e4e5d9e60267e864b'), ObjectId('5403f3db21715eed7bc3b259')),
#  (ObjectId('546faa6f4e5d9e60267e864c'), ObjectId('5407e330c3ee225472776741')),
#  (ObjectId('546faa774e5d9e60267e8675'), ObjectId('5408aa0d318ae5c60424b17f')),
#  (ObjectId('546faa754e5d9e60267e8668'), ObjectId('54087d886c86596954df9f1a')),
#  (ObjectId('546faa714e5d9e60267e8657'), ObjectId('5400a9508f68b3e812b6a5b9')),
#  (ObjectId('546faa8d4e5d9e60267e86b1'), ObjectId('5409afbfe85f852d7ea409a7')),
#  (ObjectId('546faab84e5d9e60267e873c'), ObjectId('540b5aa0ea2c4ce92dfe28b5')),
#  (ObjectId('546faab94e5d9e60267e8745'), ObjectId('5408818cf7ab41255ffbb1cf')),
#  (ObjectId('546faabf4e5d9e60267e874d'), ObjectId('53ba85c966212bf30b000075')),
#  (ObjectId('546faac44e5d9e60267e875b'), ObjectId('540a70e3c7f549d05700e167')),
#  (ObjectId('546faaff4e5d9e60267e87f7'), ObjectId('540c09a16d2a07d66e849b3c')),
#  (ObjectId('546fab034e5d9e60267e8806'), ObjectId('540cea44e38ee74b4c91ef52')),
#  (ObjectId('546fab164e5d9e60267e8840'), ObjectId('540e4b9fda77d6502e4c3255')),
#  (ObjectId('546fab334e5d9e60267e889a'), ObjectId('540bda5f658caaa04f5528c8')),
#  (ObjectId('546fab424e5d9e60267e88dd'), ObjectId('5400e9c392a7f2833aa91cc3')),
#  (ObjectId('546fc8fa3dd308f1b5747157'), ObjectId('541016cdb47e023e6af58e82')),
#  (ObjectId('546fc91f3dd308f1b57471ba'), ObjectId('540c78fa9c96f3ef455942e1')),
#  (ObjectId('546fc9253dd308f1b57471cd'), ObjectId('54138150a4c31a3c34eaf656')),
#  (ObjectId('546fc9343dd308f1b57471f0'), ObjectId('54136ad8a4c31a3c34eaf052')),
#  (ObjectId('546fca443dd308f1b57472d2'), ObjectId('5417fe24d608fd2c5659ceeb')),
#  (ObjectId('546fca4f3dd308f1b57472fc'), ObjectId('5418e7a2ee80e3c511e9b661')),
#  (ObjectId('546fcaa23dd308f1b574741c'), ObjectId('541a7eae9a5dd267602a8268')),
#  (ObjectId('546fcab63dd308f1b574745b'), ObjectId('541ea657d4713d77459bd75c')),
#  (ObjectId('546fcad73dd308f1b57474b9'), ObjectId('541f73b7022f01fe7e28143c')),
#  (ObjectId('546fce213dd308f1b57475cf'), ObjectId('54230f6a3dcd84450c585e20')),
#  (ObjectId('546fce5f3dd308f1b574761c'), ObjectId('5422d1813dcd84450c584e06')),
#  (ObjectId('546fce9a3dd308f1b57476bc'), ObjectId('5426fbe938820d7e53260fb7')),
#  (ObjectId('546fce983dd308f1b57476b5'), ObjectId('540c95846946cf9f6524ee59')),
#  (ObjectId('546fce9e3dd308f1b57476c7'), ObjectId('5427174f82f54cbd64c93784')),
#  (ObjectId('546fce9f3dd308f1b57476c8'), ObjectId('5427173f82f54cbd64c93777')),
#  (ObjectId('546fcee33dd308f1b5747712'), ObjectId('542759cf82f54cbd64c94dda')),
#  (ObjectId('546fcee33dd308f1b5747714'), ObjectId('541b16e027ddb4115f7e5dd9')),
#  (ObjectId('546fcf1b3dd308f1b57477a9'), ObjectId('53d4289f39e9d09b63000067')),
#  (ObjectId('546fcf213dd308f1b57477c4'), ObjectId('5429f62d6cf019f1544aa7f6')),
#  (ObjectId('546fcf293dd308f1b57477e1'), ObjectId('541d0a8f0b0c20fd7f008d02')),
#  (ObjectId('546fcf2e3dd308f1b57477f6'), ObjectId('542a9f0c6cf019f1544acc7d')),
#  (ObjectId('546fcf733dd308f1b57478af'), ObjectId('542beba0be5925755b75812d')),
#  (ObjectId('546fcf953dd308f1b574790d'), ObjectId('542d4c8061de517a40f65ff8')),
#  (ObjectId('546fcfbe3dd308f1b574797d'), ObjectId('542eaf86e54dcf95795b07db')),
#  (ObjectId('546fcfc63dd308f1b574798b'), ObjectId('542e0326a0f22d4304a4407c')),
#  (ObjectId('546fcffc3dd308f1b5747a11'), ObjectId('542310d63dcd84450c585e9b')),
#  (ObjectId('546fd0073dd308f1b5747a2c'), ObjectId('542c942661de517a40f642b8')),
#  (ObjectId('546fd15b3dd308f1b5747c68'), ObjectId('5437f8aaefc2c9f650a0b460')),
#  (ObjectId('546fd1c43dd308f1b5747d27'), ObjectId('5434687205543b856c8459a8')),
#  (ObjectId('546fd22d3dd308f1b5747deb'), ObjectId('5435a64e406d71c63b9fa39c')),
#  (ObjectId('546fd2a23dd308f1b5747fd3'), ObjectId('543becf6e8981e637ff227c1')),
#  (ObjectId('546fd2923dd308f1b5747fb3'), ObjectId('543b065be37c1e493dd20e20')),
#  (ObjectId('546fd3e03dd308f1b57481f3'), ObjectId('543ec69a625c0ba9391f7c5c')),
#  (ObjectId('546fd3f13dd308f1b574820f'), ObjectId('543ec7f0625c0ba9391f7e2a')),
#  (ObjectId('546fd43f3dd308f1b57482a8'), ObjectId('543ffe5cc46b45543d807601')),
#  (ObjectId('546fd4993dd308f1b5748356'), ObjectId('543b72d17434b70639d544d9')),
#  (ObjectId('546fd4e23dd308f1b57483d1'), ObjectId('5442adcbee40d48135caeb21')),
#  (ObjectId('546fd4e93dd308f1b57483de'), ObjectId('543453ffbf0cce2244110a3e')),
#  (ObjectId('546fd55a3dd308f1b57484a1'), ObjectId('5432c1bc81a4bd195ae22f75')),
#  (ObjectId('546fd55f3dd308f1b57484aa'), ObjectId('5443fc6e5aa20136322875ec')),
#  (ObjectId('546fd5843dd308f1b57484e4'), ObjectId('543009d1e4251e5e66ec259c')),
#  (ObjectId('546fd58f3dd308f1b57484f8'), ObjectId('5442ce29ee40d48135caf991')),
#  (ObjectId('546fd5a83dd308f1b5748520'), ObjectId('5445348b85786cae6b6ca945')),
#  (ObjectId('546fd58e3dd308f1b57484f5'), ObjectId('544529cd85786cae6b6ca4cd')),
#  (ObjectId('546fd7443dd308f1b57487f9'), ObjectId('54280705834c171f1393168b')),
#  (ObjectId('546fd76e3dd308f1b5748845'), ObjectId('54437421595b452d13192a9b')),
#  (ObjectId('546fd78e3dd308f1b574888a'), ObjectId('54142de2e980e3ce042f8dbf')),
#  (ObjectId('546fd7d73dd308f1b5748901'), ObjectId('54273c7e82f54cbd64c9458f')),
#  (ObjectId('546fd8753dd308f1b5748a4f'), ObjectId('544d9235288e1c075931bd3d')),
#  (ObjectId('546fd8653dd308f1b5748a2a'), ObjectId('544d6238288e1c075931a684')),
#  (ObjectId('546fd8ef3dd308f1b5748b3a'), ObjectId('5442ddbbee40d48135cb004f')),
#  (ObjectId('546fd9403dd308f1b5748bf4'), ObjectId('53aa181ace8b24704f000001')),
#  (ObjectId('546fd9493dd308f1b5748c0a'), ObjectId('534e6f8a8929bdf64200041d')),
#  (ObjectId('546fda0c3dd308f1b5748d45'), ObjectId('53dd8ff5a4135c842a0052a7')),
#  (ObjectId('546fda793dd308f1b5748e3a'), ObjectId('5436100fc95f5e981d7c071f')),
#  (ObjectId('546fdaaf3dd308f1b5748eb7'), ObjectId('5452eaeb3326549c633c8d1d')),
#  (ObjectId('546fdbb73dd308f1b57490fd'), ObjectId('545655e3557018ee771f9312')),
#  (ObjectId('546fdbfd3dd308f1b5749196'), ObjectId('542ed858a196718a6f55f941')),
#  (ObjectId('546fdc7c3dd308f1b5749292'), ObjectId('5436b4b1857de95413083c8a')),
#  (ObjectId('546fdd033dd308f1b57493b1'), ObjectId('54208c71a1fa95522057792b')),
#  (ObjectId('546fddda3dd308f1b574956f'), ObjectId('545a843bab53467540c3ba85')),
#  (ObjectId('546fdf9a3dd308f1b5749908'), ObjectId('54592f02289a0664534e069b')),
#  (ObjectId('546fdf9e3dd308f1b5749916'), ObjectId('545cf04e38ad3f8e2f7db217')),
#  (ObjectId('546fdfdd3dd308f1b5749994'), ObjectId('545e324457b9917218494582')),
#  (ObjectId('546fe0ce3dd308f1b5749c63'), ObjectId('546102083c6d36f109bb922e')),
#  (ObjectId('546fe0ac3dd308f1b5749c22'), ObjectId('5460d89b55a771ce1db23525')),
#  (ObjectId('546fe10b3dd308f1b5749cc7'), ObjectId('5459723fc80c82aa2984a84e')),
#  (ObjectId('546fe1113dd308f1b5749cdb'), ObjectId('54609dd14096917c14bf19f1')),
#  (ObjectId('546fe15f3dd308f1b5749d5e'), ObjectId('540098311e29810f09d5238d')),
#  (ObjectId('546fe19c3dd308f1b5749de7'), ObjectId('54622c85932e0cfb31af5b81')),
#  (ObjectId('546fe1de3dd308f1b5749e72'), ObjectId('54628b4ef3a40e0044ad97a6')),
#  (ObjectId('546fe1e43dd308f1b5749e81'), ObjectId('546166540b2e9233678ae468')),
#  (ObjectId('546fe28d3dd308f1b5749fc4'), ObjectId('54617cecd9a5e9dc19b24aff')),
#  (ObjectId('546fe3943dd308f1b574a1ad'), ObjectId('5465623d458d3fca24aa9691')),
#  (ObjectId('546ff2afd8d4671a22bb8045'), ObjectId('5465c1f5c6f7a4785ac9eb60')),
#  (ObjectId('546ff3e3d8d4671a22bb81f6'), ObjectId('5467c3d650184a0d52d798c3')),
#  (ObjectId('546ff424d8d4671a22bb82ca'), ObjectId('544f144d982486d94bee4b6e')),
#  (ObjectId('546ff442d8d4671a22bb8324'), ObjectId('54680d3932f6973a75e326ee')),
#  (ObjectId('546ff45bd8d4671a22bb8371'), ObjectId('540cf71ef5604aaa5d275595')),
#  (ObjectId('546ff4e0d8d4671a22bb8533'), ObjectId('54668c15f695384275fe618a')),
#  (ObjectId('546ff519d8d4671a22bb85ff'), ObjectId('545baf4ea1f0bb3a5f7a34fe')),
#  (ObjectId('546ff50ed8d4671a22bb85d4'), ObjectId('545c8ac738ad3f8e2f7d7716')),
#  (ObjectId('546ff599d8d4671a22bb87d9'), ObjectId('546d1548168007e959097ff6')),
#  (ObjectId('546ff5c7d8d4671a22bb887b'), ObjectId('546ccf8efc89e1f633606c4a')),
#  (ObjectId('546ff5cbd8d4671a22bb8888'), ObjectId('54613e6900a6994261614069')),
#  (ObjectId('546ff600d8d4671a22bb895a'), ObjectId('54349981aba3ed8a75f9b068')),
#  (ObjectId('547096a2d8d4671a22bb96bc'), ObjectId('54689e025fabd55717234c66')),
#  (ObjectId('5470d99ed8d4671a22bb9c88'), ObjectId('5424adaa78f1aa123ee7284b')),
#  (ObjectId('5470cec9d8d4671a22bb9b63'), ObjectId('5470cb8b86ad940567d29b30')),
#  (ObjectId('5470e07ed8d4671a22bb9da7'), ObjectId('5470dd8b0848f80416586285')),
#  (ObjectId('5470f751d8d4671a22bb9edf'), ObjectId('5470cc4286ad940567d29b71')),
#  (ObjectId('547117dcd8d4671a22bba258'), ObjectId('547116d790a988a57598507d')),
#  (ObjectId('547137d9d8d4671a22bba4b1'), ObjectId('547136476152ee93425f59bb')),
#  (ObjectId('54713ae5d8d4671a22bba4b6'), ObjectId('547138fd6152ee93425f5da5')),
#  (ObjectId('54719bd9d8d4671a22bbacc3'), ObjectId('546561f6458d3fca24aa9679')),
#  (ObjectId('5471ae28d8d4671a22bbadeb'), ObjectId('53de57c089ee804c150011cb')),
#  (ObjectId('5471afb3d8d4671a22bbadee'), ObjectId('53de677989ee804c15001d5a')),
#  (ObjectId('5472264ed8d4671a22bbb84f'), ObjectId('5472240bf577eb93600b89d1')),
#  (ObjectId('5473a012d8d4671a22bbd7e3'), ObjectId('54739e65273a7c2d01026aaa')),
#  (ObjectId('54739a8cd8d4671a22bbd6be'), ObjectId('540e1c95d16ce9727cfed88f')),
#  (ObjectId('5474b27bd8d4671a22bbee12'), ObjectId('5474b0dde4a3b0bd76b3c404')),
#  (ObjectId('5474bd87d8d4671a22bbef3b'), ObjectId('5474bc409ae797912a14357b')),
#  (ObjectId('5474c19dd8d4671a22bbef4a'), ObjectId('5474c0b429d0f0f0414485cc')),
#  (ObjectId('5474d0f3d8d4671a22bbf08d'), ObjectId('5474cf0e1b469c8d6a2084b4')),
#  (ObjectId('5474e62ed8d4671a22bbf2eb'), ObjectId('5474e4e6c6f4068e32be9dd9')),
#  (ObjectId('5474fd26d8d4671a22bbf54c'), ObjectId('5474fb9245868e085e7e2673')),
#  (ObjectId('547508afd8d4671a22bbf568'), ObjectId('547506beaf182f22100b8f0c')),
#  (ObjectId('5475637ad8d4671a22bbfd94'), ObjectId('546c6c45c856e0e37937f15d')),
#  (ObjectId('5475adefd8d4671a22bc4e9e'), ObjectId('544b144869e929ee0e3e12f7')),
#  (ObjectId('5476160cb76485d289801ab4'), ObjectId('547613c925420b92668a060b')),
#  (ObjectId('54762e1eb76485d289801bf7'), ObjectId('5476269091d63e077bc0ea36')),
#  (ObjectId('54764197b76485d289801e4e'), ObjectId('547640559b1fb42a4ab34d4f')),
#  (ObjectId('5476545ab76485d289801f86'), ObjectId('547652d2feb171ad102e1165')),
#  (ObjectId('5476b6c0b76485d2898027c1'), ObjectId('5476b4c980bee3ac3af5d53a')),
#  (ObjectId('54781e85b76485d2898045c6'), ObjectId('54781c4efb4642f9137dc9c6')),
#  (ObjectId('547818bfb76485d2898044ab'), ObjectId('5478172efb4642f9137dc870')),
#  (ObjectId('547834b9b76485d2898046fd'), ObjectId('5478334a201f494a43ad4ec9')),
#  (ObjectId('547895ccb76485d289804f05'), ObjectId('5478771071e213aa0e47a6c9')),
#  (ObjectId('54790cd8b76485d2898059a8'), ObjectId('54790b901574b59318507938')),
#  (ObjectId('547929c5b76485d289805bfe'), ObjectId('547927217d6c6951572e32fa')),
#  (ObjectId('547a3108b76485d289807117'), ObjectId('547831ed201f494a43ad4e01')),
#  (ObjectId('547a58e4b76485d28980749d'), ObjectId('547a4a6601dd13aa3fe0c642')),
#  (ObjectId('547a5d40b76485d2898074a3'), ObjectId('547a5cd92e05d25c04a0dc75')),
#  (ObjectId('547b7971b76485d289808d40'), ObjectId('547b7718bf52058211432dd0')),
#  (ObjectId('547cb085b76485d28980a75c'), ObjectId('547cae3f82a8cebf4b4009ee')),
#  (ObjectId('547d03dcb76485d28980aedc'), ObjectId('547cc3e6b282530d19a57d1e')),
#  (ObjectId('547d26e8b76485d28980b155'), ObjectId('547d00168f9759a252b88325')),
#  (ObjectId('547d3751b76485d28980b292'), ObjectId('547cd93d3dfa511d59467a46')),
#  (ObjectId('547d2743b76485d28980b156'), ObjectId('547cd2a675a1b32b28de3a14')),
#  (ObjectId('547d7cd7b76485d28980b867'), ObjectId('547d48f3f6b7e4e6435bb8aa')),
#  (ObjectId('547ddd92b76485d28980c0b8'), ObjectId('547dcac93cb89ecb3d64fd4a')),
#  (ObjectId('547ded9ab76485d28980c1f5'), ObjectId('547dd7f0d9bdd7904a8c99f1')),
#  (ObjectId('547e2481b76485d28980c6eb'), ObjectId('547df7534f03a2a526d53584')),
#  (ObjectId('547ea21ab76485d28980d1de'), ObjectId('547e45906a96b4de17426e0c')),
#  (ObjectId('547ea61bb76485d28980d1e4'), ObjectId('546c0a89b5977c3b5553488c')),
#  (ObjectId('547ef1bdb76485d28980d8f4'), ObjectId('547e99e2fbf9c00f0e9a2678')),
#  (ObjectId('547f67a5b76485d28980e2bc'), ObjectId('54427ec6ee40d48135cad7a1')),
#  (ObjectId('547f6f8db76485d28980e3ee'), ObjectId('547f32962ba4095704381140')),
#  (ObjectId('547f7028b76485d28980e3f2'), ObjectId('547f35f3381cedde3ad1b937')),
#  (ObjectId('547f7e3ab76485d28980e529'), ObjectId('547f440e5f4e66fd41cd25ea')),
#  (ObjectId('547fa2a3b76485d28980e7bd'), ObjectId('547f891a141be2d93f379d0c')),
#  (ObjectId('547fd28fb76485d28980ec82'), ObjectId('5384bd358922095f0c00001a')),
#  (ObjectId('54816444b76485d289810ea1'), ObjectId('54812f0e7051086676b6d104')),
#  (ObjectId('5481b655b76485d2898115d9'), ObjectId('5481297a7051086676b6cdaa')),
#  (ObjectId('54822ce7b76485d2898120e8'), ObjectId('5432c59081a4bd195ae22fe3')),
#  (ObjectId('5482609db76485d2898124a2'), ObjectId('5482333db27204612e8895a6')),
#  (ObjectId('5482f511b76485d2898131b4'), ObjectId('548206e324985b9c6d6cd992')),
#  (ObjectId('54830ed7b76485d289813425'), ObjectId('548211e317f2550817700e1e')),
#  (ObjectId('54833302b76485d2898136ae'), ObjectId('548320319e8dcb2a4a3b426c')),
#  (ObjectId('54835f0fb76485d289813a78'), ObjectId('54828e726f8f7c1a31155d36')),
#  (ObjectId('54835fb6b76485d289813a7c'), ObjectId('548276246f8f7c1a31154ed0')),
#  (ObjectId('5483b3dbb76485d2898141d2'), ObjectId('5482e3ebfa88722b798b6fd1')),
#  (ObjectId('5483c906b76485d289814433'), ObjectId('5482f579fa88722b798b7b9c')),
#  (ObjectId('5484064eb76485d289814908'), ObjectId('548348aeda391a8257f6ecf6')),
#  (ObjectId('54852ed8b76485d28981627a'), ObjectId('5483bab46439d35f56221fdf')),
#  (ObjectId('54852ee0b76485d28981628e'), ObjectId('5483dd50e64aa97d3bb9a107')),
#  (ObjectId('54857a1eb76485d2898169f2'), ObjectId('5484be8734b4d12361334021')),
#  (ObjectId('54859216b76485d289816b44'), ObjectId('5484fc89fe3aa4dd54245b7b')),
#  (ObjectId('54860b43b76485d2898176fd'), ObjectId('5485ad7c7023ed9e428c82cd')),
#  (ObjectId('54864edeb76485d289817db9'), ObjectId('5485fe8f920a391b7998a240')),
#  (ObjectId('54865b3eb76485d289817eff'), ObjectId('548606564bdf023065fe7577')),
#  (ObjectId('5486a399b76485d289818567'), ObjectId('54865c5c79740161398b1720')),
#  (ObjectId('5486b91bb76485d2898186bd'), ObjectId('5486681dd282201e4ae29b1a')),
#  (ObjectId('54877918b76485d2898198c1'), ObjectId('54875ba9fdac85d6755db9fa')),
#  (ObjectId('54887b00b76485d28981afab'), ObjectId('529fafbefb42d4a65000001e')),
#  (ObjectId('548897b2b76485d28981b340'), ObjectId('548881fff4840de20e7a6607')),
#  (ObjectId('5488c5eab76485d28981ba31'), ObjectId('547cccc775a1b32b28de360e')),
#  (ObjectId('5489e6fcb76485d28981ea50'), ObjectId('5489cede2a9def9c5c8a892d')),
#  (ObjectId('5489f5b5b76485d28981ed04'), ObjectId('5489e30ba29f11fa035f13b8')),
#  (ObjectId('548a0d24b76485d28981f1ce'), ObjectId('5489f96c2f2b01973bd22b95')),
#  (ObjectId('548a4494b76485d28981fc37'), ObjectId('548a101ab0b8f31774d9fb8a')),
#  (ObjectId('548accc4b76485d289821534'), ObjectId('5488960e9cc56047470b3b18')),
#  (ObjectId('548b3b45b76485d289822779'), ObjectId('540b8ad286d1d1775c659015')),
#  (ObjectId('548b9cbeb76485d2898238b2'), ObjectId('54108cb4be6a6da508ede8b9')),
#  (ObjectId('548ca349b76485d289825fae'), ObjectId('548c2acf10d1edf459be3d1e')),
#  (ObjectId('548ca94ab76485d289826195'), ObjectId('548c983024310ebb77d3d225')),
#  (ObjectId('548cd787b76485d28982699a'), ObjectId('548c5c1fe12603b43f98fa63')),
#  (ObjectId('548d3769b76485d289827927'), ObjectId('543eb99a625c0ba9391f705f')),
#  (ObjectId('548d395ab76485d28982794a'), ObjectId('548c9e257db92af2225b8320')),
#  (ObjectId('548da533b76485d289828a94'), ObjectId('548d0fc97a565eef3f408e10')),
#  (ObjectId('548df400b76485d2898299aa'), ObjectId('54540f95f25c24c21da84fcc')),
#  (ObjectId('548e2eb1b76485d28982a4d1'), ObjectId('5484f9b1fe3aa4dd5424594f')),
#  (ObjectId('548e41fab76485d28982a999'), ObjectId('548dc8c09d9fa52e24755fe4')),
#  (ObjectId('548f322eb76485d28982d5ff'), ObjectId('546a7ba31958902a2fd42158')),
#  (ObjectId('548f64a2b76485d28982dec0'), ObjectId('548e6e597255aaa90b531f9c')),
#  (ObjectId('548f651cb76485d28982dec9'), ObjectId('546cf10a2f06e0976e57d3f4')),
#  (ObjectId('548fbe63b76485d28982f03b'), ObjectId('548f97c0473ffb652e15b716')),
#  (ObjectId('548fd6e4b76485d28982f384'), ObjectId('548f7dac80e5ca2670b8075b')),
#  (ObjectId('549010cab76485d28982fe0b'), ObjectId('548fc237bc9e5ad126704f0b')),
#  (ObjectId('54902245b76485d28983028c'), ObjectId('547b59a523f4734a4c682dfe')),
#  (ObjectId('5490b198b76485d289831dc9'), ObjectId('54908f3d065971620c72b940')),
#  (ObjectId('5490c28db76485d2898320ac'), ObjectId('5490ae3cd61466874b3fddba')),
#  (ObjectId('5490ec86b76485d2898327a1'), ObjectId('5490e668a0ac11d80ca3b8ca')),
#  (ObjectId('5491b3a2b76485d289833f05'), ObjectId('5491b13443092ed26b889622')),
#  (ObjectId('5491ad2bb76485d289833efc'), ObjectId('5491a883bd0c5d56553f71f8')),
#  (ObjectId('54924396b76485d2898351ae'), ObjectId('54922936bfa46bcd0167edd4')),
#  (ObjectId('54929be2b76485d289835b92'), ObjectId('549296f5636109c202371759')),
#  (ObjectId('549323eab76485d289836a81'), ObjectId('5492ee35256c06d21657ea74')),
#  (ObjectId('54932641b76485d289836c1a'), ObjectId('541f6928022f01fe7e28110e')),
#  (ObjectId('54933075b76485d289836c2e'), ObjectId('54932fb1289a530046030d7a')),
#  (ObjectId('54939384b76485d289837808'), ObjectId('549358804231505b194d94be')),
#  (ObjectId('549453e9b76485d289838f99'), ObjectId('54944c349aff193d7f4529ad')),
#  (ObjectId('5494b614b76485d289839b88'), ObjectId('5494a51a6dc07f392527e430')),
#  (ObjectId('5494b9f0b76485d289839b8f'), ObjectId('5494a7cb6dc07f392527e794')),
#  (ObjectId('5494ba4bb76485d289839b93'), ObjectId('5494a9aa6dc07f392527e9f9')),
#  (ObjectId('5494cd61b76485d289839eee'), ObjectId('5494b3976dc07f392527f062')),
#  (ObjectId('5494dc41b76485d28983a09f'), ObjectId('5494b98b6dc07f392527f31a')),
#  (ObjectId('549512a1b76485d28983a758'), ObjectId('5494fcc64c70768a3d2ab5ef')),
#  (ObjectId('549518cbb76485d28983a761'), ObjectId('54950bc2f8bcd763741abef2')),
#  (ObjectId('54965e4cb76485d28983cdff'), ObjectId('54963c3782cec5844b724f65')),
#  (ObjectId('5496acabb76485d28983d7f0'), ObjectId('5496981bc38c9fd9504442f0')),
#  (ObjectId('549708c7b76485d28983e223'), ObjectId('5496fd39a8ae30b160d262dc')),
#  (ObjectId('54971057b76485d28983e3ca'), ObjectId('549700bfa8ae30b160d26461')),
#  (ObjectId('54978ec3b76485d28983f294'), ObjectId('5497327b8cdf4b53785ad094')),
#  (ObjectId('54978ee2b76485d28983f2d2'), ObjectId('54973b848cdf4b53785ad67c')),
#  (ObjectId('5497a2dcb76485d28983f4a2'), ObjectId('54977176743d5f8342506a5a')),
#  (ObjectId('5497f529b76485d28983fe92'), ObjectId('5497f4bd63603c6a5e181f54')),
#  (ObjectId('549885b4b76485d289840fa4'), ObjectId('5498708c4eafed015218ce65')),
#  (ObjectId('54988f08b76485d28984114d'), ObjectId('549877094eafed015218d32d')),
#  (ObjectId('54988faeb76485d28984114f'), ObjectId('549879ca4eafed015218d4b1')),
#  (ObjectId('54992c08b76485d289842403'), ObjectId('540a3f2bad5a9034123afe7b')),
#  (ObjectId('549a0858b76485d289843f2b'), ObjectId('5499e32710ceedc20d76fa1b')),
#  (ObjectId('549a3182b76485d289844440'), ObjectId('549a29940fa0cc4515916469')),
#  (ObjectId('549a3d37b76485d2898445e4'), ObjectId('549a158ff19714dd56504cba')),
#  (ObjectId('549a3f3ab76485d2898445e6'), ObjectId('53dca779a4135c842a0005f1')),
#  (ObjectId('549b8851b76485d289846c4b'), ObjectId('549b8232b4837ddd249b99bf')),
#  (ObjectId('549c1acdb76485d289847ea0'), ObjectId('549c179536633a73145effc3')),
#  (ObjectId('549cc4cab76485d2898492ea'), ObjectId('549cb95770da88b1329796d8')),
#  (ObjectId('549ce588b76485d289849656'), ObjectId('545faf45f267d4db03af8bd2')),
#  (ObjectId('549d9382b76485d28984aa99'), ObjectId('549d82ed4863d3923ecff65e')),
#  (ObjectId('549dd0f2b76485d28984b331'), ObjectId('549dcfa034bb65125cbb429a')),
#  (ObjectId('549edfedb76485d28984d354'), ObjectId('549ed299d26bdab3098af91c')),
#  (ObjectId('549f516db76485d28984e10c'), ObjectId('52e834812ff24f7513000002')),
#  (ObjectId('549f83e8b76485d28984e7cf'), ObjectId('549f6ee6fe351ff64735343c')),
#  (ObjectId('54a0ae7ab76485d289850bc4'), ObjectId('54a08c1f29ed8a4c39a55eb4')),
#  (ObjectId('54a19134b76485d28985271e'), ObjectId('54a1864e4977ad9a70bdf8bb')),
#  (ObjectId('54a1a129b76485d2898528dc'), ObjectId('5414c8c4e980e3ce042fb4fe')),
#  (ObjectId('54a1ba00b76485d289852c60'), ObjectId('54a1b6dd998ff6902d2aa519')),
#  (ObjectId('54a2579fb76485d289853f7c'), ObjectId('54a20a53d5f0a49b797677ab')),
#  (ObjectId('54a2862fb76485d28985463d'), ObjectId('54a26ba00d07e0ed20cdf62e')),
#  (ObjectId('54a2db7ab76485d2898550aa'), ObjectId('54a2cd045e1ef8c80362d334')),
#  (ObjectId('54a4672cb76485d289858057'), ObjectId('546742b950a4cc6458bdbdf5')),
#  (ObjectId('54a49e76b76485d289858717'), ObjectId('54a438e3f58d82b93ffe3ff7')),
#  (ObjectId('54a583e4b76485d28985a1f1'), ObjectId('54a461562a1c76bb10223ef9')),
#  (ObjectId('54a66a1fb76485d28985bd2f'), ObjectId('542a944a6cf019f1544aca5e'))]

# %%
count = 0
rmse  = []
unproc_rmse = []
proc_rmse = []
good_rmse  = []
bad_rmse  = []
med_rmse = []
good_proc_id = []
bad_proc_id = []
med_proc_id = []

for i in range(len(proc_id)):
    proc_status = 0
    track_filenames = []
    
    post_id = proc_id[i][0]
    song_id = proc_id[i][1]
    
    volume_settings, volume_channels, ogg_paths, start_times = get_mixing_coeff(num_pub_track, song_id, post_id, proc_status)
    if len(ogg_paths) is 0:
        proc_status = 1
        volume_settings, volume_channels, ogg_paths, start_times = get_mixing_coeff(num_pub_track, song_id, post_id, proc_status)
        
    if len(ogg_paths) is not num_pub_track:
            count +=1
            continue
    else:
        for j in range(num_pub_track):
            download_track(ogg_paths[j])
            track_filenames.append(get_filename(ogg_paths[j])) 
    
    pointer = vidCol.find({'songId': song_id})
    for songdocs in pointer:
        bandhub_mix = songdocs['oggMergedVideoUrl']

    download_track(bandhub_mix)

    ogg_tracks, mixsr = match_track_lengths(num_pub_track,track_filenames,start_times)
    if mixsr is -1:
        continue

    mix_ogg = compute_estimated_mix(num_pub_track, volume_channels, ogg_tracks, mixsr)
    sf.write('mixed.wav', mix_ogg / np.max(np.abs(mix_ogg)), mixsr)

    for premix in os.listdir('.'):
        if fnmatch.fnmatch(premix, 'f-*'):
            rename_cmd = ['mv', premix, 'premix.ogg']
            s1 = subprocess.call(rename_cmd)
            if s1 is 0:
                #print('Rename success!')
                convert_cmd = ['ffmpeg', '-i', 'premix.ogg', '-vsync', '1', '-async', '1', '-vn', 'premix.wav']
                s2 = subprocess.call(convert_cmd)
                if s2 is not 0:
                    continue

            else:
                #print('ERROR: Rename failed!')
                continue

    if s2 is 0:

        bandhub_mix, sr = sf.read('premix.wav')
        estimated_mix, sr = sf.read('mixed.wav')
        estimated_mix_spec,bandhub_mix_spec = compute_offset_and_shift(estimated_mix, bandhub_mix, sr)
        diff_mix_data = get_diff_mix_data(estimated_mix_spec,bandhub_mix_spec)
        root_mean_sq_error = round(np.mean((diff_mix_data)**2),2)
        
        if proc_status is 0:
            unproc_rmse.append(root_mean_sq_error)
        else:
            proc_rmse.append(root_mean_sq_error)
            
        rmse.append(root_mean_sq_error)
        
        if root_mean_sq_error < 5:
            good_rmse.append((song_id,root_mean_sq_error))
            good_proc_id.append(proc_id[i])
        elif root_mean_sq_error > 150:
            bad_rmse.append((song_id,root_mean_sq_error))
            bad_proc_id.append(proc_id[i])
        elif root_mean_sq_error > 75 and root_mean_sq_error < 80:
            med_rmse.append((song_id,root_mean_sq_error))
            med_proc_id.append(proc_id[i])
    
    clear_downloads()
# Out:
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (14888512, 2)
# (14888512, 2)
# (14888512, 2)
# (15010368,)
# (15010368,)
# /home/rrs432/miniconda2/envs/bandhub/lib/python2.7/site-packages/librosa/core/spectrum.py:958: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(magphase(D)[0]) instead.
#   warnings.warn('amplitude_to_db was called on complex input so phase '
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (3352512, 2)
# (3352512, 2)
# (3352512, 2)
# (3355712,)
# (3355712,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9906176, 2)
# (9906176, 2)
# (9906176, 2)
# (9906176,)
# (9906176,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (15507392, 2)
# (15507392, 2)
# (15507392, 2)
# (15509568,)
# (15509568,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# Missing published track!
# Unprocessed audio URL
# Missing published track!
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# Missing published track!
# Unprocessed audio URL
# Missing published track!
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (11210560, 2)
# (11210560, 2)
# (11210560, 2)
# (11212096,)
# (11212096,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (5731200, 2)
# (5731200, 2)
# (5731200, 2)
# (5734720,)
# (5734720,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8972096, 2)
# (8972096, 2)
# (8972096, 2)
# (8976064,)
# (8976064,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (7935808, 2)
# (7935808, 2)
# (7935808, 2)
# (7939008,)
# (7939008,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (16878528, 2)
# (16878528, 2)
# (16878528, 2)
# (16881856,)
# (16881856,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (16492569, 2)
# (16492569, 2)
# (16492569, 2)
# (16496576,)
# (16496576,)
# Unprocessed audio URL
# Processed audio URL
# Processed audio URL
# Unprocessed audio URL
# Processed audio URL
# Processed audio URL
# (10255424, 2)
# (10255424, 2)
# (10255424, 2)
# (10259136,)
# (10259136,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (11088192, 2)
# (11088192, 2)
# (11088192, 2)
# (11091264,)
# (11091264,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10918656, 2)
# (10918656, 2)
# (10918656, 2)
# (10922304,)
# (10922304,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (6905408, 2)
# (6905408, 2)
# (6905408, 2)
# (6908480,)
# (6908480,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (5695552, 2)
# (5695552, 2)
# (5695552, 2)
# (5698624,)
# (5698624,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (6280896, 2)
# (6280896, 2)
# (6280896, 2)
# (6284352,)
# (6284352,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (11011584, 2)
# (11011584, 2)
# (11011584, 2)
# (11015616,)
# (11015616,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8603840, 2)
# (8603840, 2)
# (8603840, 2)
# (8606144,)
# (8606144,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (15357156, 2)
# (15357156, 2)
# (15357156, 2)
# (15360192,)
# (15360192,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10335616, 2)
# (10335616, 2)
# (10335616, 2)
# (10339008,)
# (10339008,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (11767808, 2)
# (11767808, 2)
# (11767808, 2)
# (12071744,)
# (12071744,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (13339648, 2)
# (13339648, 2)
# (13339648, 2)
# (13343680,)
# (13343680,)
# Unprocessed audio URL
# Processed audio URL
# Processed audio URL
# Unprocessed audio URL
# Processed audio URL
# Processed audio URL
# (9140288, 2)
# (9140288, 2)
# (9140288, 2)
# (9143616,)
# (9143616,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8620736, 2)
# (8620736, 2)
# (8620736, 2)
# (8623808,)
# (8623808,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (13176503, 2)
# (13176503, 2)
# (13176503, 2)
# (13179584,)
# (13179584,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8823872, 2)
# (8823872, 2)
# (8823872, 2)
# (8827840,)
# (8827840,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8063424, 2)
# (8063424, 2)
# (8063424, 2)
# (8066496,)
# (8066496,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (11940800, 2)
# (11940800, 2)
# (11940800, 2)
# (11944256,)
# (11944256,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (18831936, 2)
# (18831936, 2)
# (18831936, 2)
# (18835136,)
# (18835136,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (14729536, 2)
# (14729536, 2)
# (14729536, 2)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9598709, 2)
# (9598709, 2)
# (9598709, 2)
# (9602240,)
# (9602240,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (12050048, 2)
# (12050048, 2)
# (12050048, 2)
# (12533440,)
# (12533440,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9839424, 2)
# (9839424, 2)
# (9839424, 2)
# (9843008,)
# (9843008,)
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# (9878400, 2)
# (9878400, 2)
# (9878400, 2)
# (9878592,)
# (9878592,)
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# (7761600, 2)
# (7761600, 2)
# (7761600, 2)
# (7762496,)
# (7762496,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10333184, 2)
# (10333184, 2)
# (10333184, 2)
# (10336448,)
# (10336448,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (11383424, 2)
# (11383424, 2)
# (11383424, 2)
# (11646784,)
# (11646784,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (13145088, 2)
# (13145088, 2)
# (13145088, 2)
# (13148992,)
# (13148992,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (13539328, 2)
# (13539328, 2)
# (13539328, 2)
# (13543360,)
# (13543360,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (11317343, 2)
# (11317343, 2)
# (11317343, 2)
# (11651520,)
# (11651520,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (11979648, 2)
# (11979648, 2)
# (11979648, 2)
# (11983168,)
# (11983168,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (12838720, 2)
# (12838720, 2)
# (12838720, 2)
# (12842432,)
# (12842432,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8305343, 2)
# (8305343, 2)
# (8305343, 2)
# (8332480,)
# (8332480,)
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# (8467200, 2)
# (8467200, 2)
# (8467200, 2)
# (8468160,)
# (8468160,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (11469312, 2)
# (11469312, 2)
# (11469312, 2)
# (11473344,)
# (11473344,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9063104, 2)
# (9063104, 2)
# (9063104, 2)
# (9066560,)
# (9066560,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (5837312, 2)
# (5837312, 2)
# (5837312, 2)
# (5840448,)
# (5840448,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9117632, 2)
# (9117632, 2)
# (9117632, 2)
# (9121088,)
# (9121088,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (11484160, 2)
# (11484160, 2)
# (11484160, 2)
# (11487808,)
# (11487808,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (11051520, 2)
# (11051520, 2)
# (11051520, 2)
# (11054144,)
# (11054144,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (13806592, 2)
# (13806592, 2)
# (13806592, 2)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (11228160, 2)
# (11228160, 2)
# (11228160, 2)
# (11231040,)
# (11231040,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (2742336, 2)
# (2742336, 2)
# (2742336, 2)
# (2745920,)
# (2745920,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10276544, 2)
# (10276544, 2)
# (10276544, 2)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8996864, 2)
# (8996864, 2)
# (8996864, 2)
# (9000896,)
# (9000896,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10280320, 2)
# (10280320, 2)
# (10280320, 2)
# (10283968,)
# (10283968,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (16800219, 2)
# (16800219, 2)
# (16800219, 2)
# (16802880,)
# (16802880,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9703424, 2)
# (9703424, 2)
# (9703424, 2)
# (9703424,)
# (9703424,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (1408256, 2)
# (1408256, 2)
# (1408256, 2)
# (1412032,)
# (1412032,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (17647616, 2)
# (17647616, 2)
# (17647616, 2)
# (17651392,)
# (17651392,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9302848, 2)
# (9302848, 2)
# (9302848, 2)
# (9305920,)
# (9305920,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (18096448, 2)
# (18096448, 2)
# (18096448, 2)
# (18124480,)
# (18124480,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (5474048, 2)
# (5474048, 2)
# (5474048, 2)
# (5477696,)
# (5477696,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (7401984, 2)
# (7401984, 2)
# (7401984, 2)
# (7405120,)
# (7405120,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (12375488, 2)
# (12375488, 2)
# (12375488, 2)
# (12378560,)
# (12378560,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (6154240, 2)
# (6154240, 2)
# (6154240, 2)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (6773440, 2)
# (6773440, 2)
# (6773440, 2)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9402624, 2)
# (9402624, 2)
# (9402624, 2)
# (9405760,)
# (9405760,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (12586560, 2)
# (12586560, 2)
# (12586560, 2)
# (12589632,)
# (12589632,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (22499328, 2)
# (22499328, 2)
# (22499328, 2)
# (22502464,)
# (22502464,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (16545792, 2)
# (16545792, 2)
# (16545792, 2)
# (16548928,)
# (16548928,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (15241600, 2)
# (15241600, 2)
# (15241600, 2)
# (15245632,)
# (15245632,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (6201088, 2)
# (6201088, 2)
# (6201088, 2)
# (6204096,)
# (6204096,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10702784, 2)
# (10702784, 2)
# (10702784, 2)
# (10704896,)
# (10704896,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8612864, 2)
# (8612864, 2)
# (8612864, 2)
# (8616640,)
# (8616640,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9866240, 2)
# (9866240, 2)
# (9866240, 2)
# (9869632,)
# (9869632,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (12632387, 2)
# (12632387, 2)
# (12632387, 2)
# (12636480,)
# (12636480,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (11481088, 2)
# (11481088, 2)
# (11481088, 2)
# (11484608,)
# (11484608,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10771456, 2)
# (10771456, 2)
# (10771456, 2)
# (10774848,)
# (10774848,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (5751744, 2)
# (5751744, 2)
# (5751744, 2)
# (5754176,)
# (5754176,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9579648, 2)
# (9579648, 2)
# (9579648, 2)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (3080576, 2)
# (3080576, 2)
# (3080576, 2)
# (3084864,)
# (3084864,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8832704, 2)
# (8832704, 2)
# (8832704, 2)
# (8835264,)
# (8835264,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8269888, 2)
# (8269888, 2)
# (8269888, 2)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (4854976, 2)
# (4854976, 2)
# (4854976, 2)
# (4858560,)
# (4858560,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10716160, 2)
# (10716160, 2)
# (10716160, 2)
# (10719808,)
# (10719808,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (12919808, 2)
# (12919808, 2)
# (12919808, 2)
# (12923200,)
# (12923200,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (15060992, 2)
# (15060992, 2)
# (15060992, 2)
# (15064384,)
# (15064384,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (21782528, 2)
# (21782528, 2)
# (21782528, 2)
# (21786176,)
# (21786176,)
# Unprocessed audio URL
# Unprocessed audio URL
# Processed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# Processed audio URL
# (20111360, 2)
# (20111360, 2)
# (20111360, 2)
# (20639040,)
# (20639040,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (17082176, 2)
# (17082176, 2)
# (17082176, 2)
# (17084736,)
# (17084736,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10725120, 2)
# (10725120, 2)
# (10725120, 2)
# (10729408,)
# (10729408,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9498624, 2)
# (9498624, 2)
# (9498624, 2)
# (9502144,)
# (9502144,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (14913536, 2)
# (14913536, 2)
# (14913536, 2)
# (14917056,)
# (14917056,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (3448576, 2)
# (3448576, 2)
# (3448576, 2)
# (3452608,)
# (3452608,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (12702720, 2)
# (12702720, 2)
# (12702720, 2)
# (12705984,)
# (12705984,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (12454912, 2)
# (12454912, 2)
# (12454912, 2)
# (12458688,)
# (12458688,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9585664, 2)
# (9585664, 2)
# (9585664, 2)
# (9589696,)
# (9589696,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9699392, 2)
# (9699392, 2)
# (9699392, 2)
# (9703360,)
# (9703360,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (11160320, 2)
# (11160320, 2)
# (11160320, 2)
# (11163584,)
# (11163584,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (7046976, 2)
# (7046976, 2)
# (7046976, 2)
# (7050048,)
# (7050048,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (12787008, 2)
# (12787008, 2)
# (12787008, 2)
# (12790720,)
# (12790720,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8329216, 2)
# (8329216, 2)
# (8329216, 2)
# (8333248,)
# (8333248,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (5649792, 2)
# (5649792, 2)
# (5649792, 2)
# (5652928,)
# (5652928,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10913792, 2)
# (10913792, 2)
# (10913792, 2)
# (10917312,)
# (10917312,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10820416, 2)
# (10820416, 2)
# (10820416, 2)
# (10824512,)
# (10824512,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8185856, 2)
# (8185856, 2)
# (8185856, 2)
# (8185856,)
# (8185856,)
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# (9172800, 2)
# (9172800, 2)
# (9172800, 2)
# (9172928,)
# (9172928,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (11198464, 2)
# (11198464, 2)
# (11198464, 2)
# (11202496,)
# (11202496,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10333312, 2)
# (10333312, 2)
# (10333312, 2)
# (10338240,)
# (10338240,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (7734720, 2)
# (7734720, 2)
# (7734720, 2)
# (7737792,)
# (7737792,)
# Unprocessed audio URL
# Unprocessed audio URL
# Processed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# Processed audio URL
# (9525600, 2)
# (9525600, 2)
# (9525600, 2)
# (9526080,)
# (9526080,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8593216, 2)
# (8593216, 2)
# (8593216, 2)
# (8596288,)
# (8596288,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9346944, 2)
# (9346944, 2)
# (9346944, 2)
# (9346944,)
# (9346944,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10353216, 2)
# (10353216, 2)
# (10353216, 2)
# (10355776,)
# (10355776,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (7234560, 2)
# (7234560, 2)
# (7234560, 2)
# (7234560,)
# (7234560,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (7300096, 2)
# (7300096, 2)
# (7300096, 2)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (11627648, 2)
# (11627648, 2)
# (11627648, 2)
# (11631040,)
# (11631040,)
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# (4939200, 2)
# (4939200, 2)
# (4939200, 2)
# (4940096,)
# (4940096,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (13321216, 2)
# (13321216, 2)
# (13321216, 2)
# (13324608,)
# (13324608,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (7534592, 2)
# (7534592, 2)
# (7534592, 2)
# (7537984,)
# (7537984,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8446964, 2)
# (8446964, 2)
# (8446964, 2)
# (8450496,)
# (8450496,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (7030592, 2)
# (7030592, 2)
# (7030592, 2)
# (7033664,)
# (7033664,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10309184, 2)
# (10309184, 2)
# (10309184, 2)
# (10312512,)
# (10312512,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (13779072, 2)
# (13779072, 2)
# (13779072, 2)
# (13782592,)
# (13782592,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (4374528, 2)
# (4374528, 2)
# (4374528, 2)
# (4376576,)
# (4376576,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (15705791, 2)
# (15705791, 2)
# (15705791, 2)
# (15708608,)
# (15708608,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (22779904, 2)
# (22779904, 2)
# (22779904, 2)
# (22783168,)
# (22783168,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (15884288, 2)
# (15884288, 2)
# (15884288, 2)
# (15887552,)
# (15887552,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9690112, 2)
# (9690112, 2)
# (9690112, 2)
# (9693760,)
# (9693760,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (11887616, 2)
# (11887616, 2)
# (11887616, 2)
# (11891264,)
# (11891264,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (13530944, 2)
# (13530944, 2)
# (13530944, 2)
# (13533248,)
# (13533248,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (11019277, 2)
# (11019277, 2)
# (11019277, 2)
# (11022656,)
# (11022656,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9743936, 2)
# (9743936, 2)
# (9743936, 2)
# (9816896,)
# (9816896,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (11865088, 2)
# (11865088, 2)
# (11865088, 2)
# (11868480,)
# (11868480,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (12204480, 2)
# (12204480, 2)
# (12204480, 2)
# (12207936,)
# (12207936,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10145792, 2)
# (10145792, 2)
# (10145792, 2)
# (10149056,)
# (10149056,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10577144, 2)
# (10577144, 2)
# (10577144, 2)
# (10581184,)
# (10581184,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8823424, 2)
# (8823424, 2)
# (8823424, 2)
# (8826560,)
# (8826560,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (12237824, 2)
# (12237824, 2)
# (12237824, 2)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (11083200, 2)
# (11083200, 2)
# (11083200, 2)
# (11086656,)
# (11086656,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (7873152, 2)
# (7873152, 2)
# (7873152, 2)
# (7877440,)
# (7877440,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (13717248, 2)
# (13717248, 2)
# (13717248, 2)
# (13720640,)
# (13720640,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (15261696, 2)
# (15261696, 2)
# (15261696, 2)
# (15265344,)
# (15265344,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (7048192, 2)
# (7048192, 2)
# (7048192, 2)
# (7051840,)
# (7051840,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10315776, 2)
# (10315776, 2)
# (10315776, 2)
# (10319040,)
# (10319040,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (4197248, 2)
# (4197248, 2)
# (4197248, 2)
# (4201408,)
# (4201408,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (2618880, 2)
# (2618880, 2)
# (2618880, 2)
# (2622528,)
# (2622528,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10989440, 2)
# (10989440, 2)
# (10989440, 2)
# (10993344,)
# (10993344,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (7728064, 2)
# (7728064, 2)
# (7728064, 2)
# (7730368,)
# (7730368,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (11311104, 2)
# (11311104, 2)
# (11311104, 2)
# (11314624,)
# (11314624,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (14192640, 2)
# (14192640, 2)
# (14192640, 2)
# (14194496,)
# (14194496,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9829312, 2)
# (9829312, 2)
# (9829312, 2)
# (9831872,)
# (9831872,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8451968, 2)
# (8451968, 2)
# (8451968, 2)
# (8456000,)
# (8456000,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (7179392, 2)
# (7179392, 2)
# (7179392, 2)
# (7182528,)
# (7182528,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (5583488, 2)
# (5583488, 2)
# (5583488, 2)
# (5586112,)
# (5586112,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9265984, 2)
# (9265984, 2)
# (9265984, 2)
# (9269056,)
# (9269056,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (7132544, 2)
# (7132544, 2)
# (7132544, 2)
# (7136576,)
# (7136576,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10772160, 2)
# (10772160, 2)
# (10772160, 2)
# (10775232,)
# (10775232,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10192064, 2)
# (10192064, 2)
# (10192064, 2)
# (10195136,)
# (10195136,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9789440, 2)
# (9789440, 2)
# (9789440, 2)
# (9793472,)
# (9793472,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10714304, 2)
# (10714304, 2)
# (10714304, 2)
# (10717376,)
# (10717376,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9123712, 2)
# (9123712, 2)
# (9123712, 2)
# (9126848,)
# (9126848,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8595456, 2)
# (8595456, 2)
# (8595456, 2)
# (8599104,)
# (8599104,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8958976, 2)
# (8958976, 2)
# (8958976, 2)
# (8962112,)
# (8962112,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10897344, 2)
# (10897344, 2)
# (10897344, 2)
# (10900416,)
# (10900416,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (7284160, 2)
# (7284160, 2)
# (7284160, 2)
# (7287104,)
# (7287104,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (6955328, 2)
# (6955328, 2)
# (6955328, 2)
# (7014848,)
# (7014848,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10919936, 2)
# (10919936, 2)
# (10919936, 2)
# (10923968,)
# (10923968,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9306112, 2)
# (9306112, 2)
# (9306112, 2)
# (9309632,)
# (9309632,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10910976, 2)
# (10910976, 2)
# (10910976, 2)
# (10914112,)
# (10914112,)
# Unprocessed audio URL
# Processed audio URL
# Processed audio URL
# Unprocessed audio URL
# Processed audio URL
# Processed audio URL
# (8801344, 2)
# (8801344, 2)
# (8801344, 2)
# (8804928,)
# (8804928,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10355712, 2)
# (10355712, 2)
# (10355712, 2)
# (10358976,)
# (10358976,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8038400, 2)
# (8038400, 2)
# (8038400, 2)
# (8041536,)
# (8041536,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (5537152, 2)
# (5537152, 2)
# (5537152, 2)
# (5540288,)
# (5540288,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8514188, 2)
# (8514188, 2)
# (8514188, 2)
# (8517312,)
# (8517312,)
# Unprocessed audio URL
# Unprocessed audio URL
# Processed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# Processed audio URL
# (8379000, 2)
# (8379000, 2)
# (8379000, 2)
# (8379328,)
# (8379328,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (12516800, 2)
# (12516800, 2)
# (12516800, 2)
# (12519872,)
# (12519872,)
# Unprocessed audio URL
# Unprocessed audio URL
# Processed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# Processed audio URL
# (8733248, 2)
# (8733248, 2)
# (8733248, 2)
# (8736192,)
# (8736192,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9276480, 2)
# (9276480, 2)
# (9276480, 2)
# (9280320,)
# (9280320,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8015936, 2)
# (8015936, 2)
# (8015936, 2)
# (8019008,)
# (8019008,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (17566720, 2)
# (17566720, 2)
# (17566720, 2)
# (17569984,)
# (17569984,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (6975168, 2)
# (6975168, 2)
# (6975168, 2)
# (6979008,)
# (6979008,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9108480, 2)
# (9108480, 2)
# (9108480, 2)
# (9112512,)
# (9112512,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8717888, 2)
# (8717888, 2)
# (8717888, 2)
# (8721472,)
# (8721472,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (12133504, 2)
# (12133504, 2)
# (12133504, 2)
# (12137536,)
# (12137536,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (15108032, 2)
# (15108032, 2)
# (15108032, 2)
# (15782464,)
# (15782464,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (12346368, 2)
# (12346368, 2)
# (12346368, 2)
# (12346368,)
# (12346368,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10373440, 2)
# (10373440, 2)
# (10373440, 2)
# (10377152,)
# (10377152,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9610240, 2)
# (9610240, 2)
# (9610240, 2)
# (9613376,)
# (9613376,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (6311744, 2)
# (6311744, 2)
# (6311744, 2)
# (6315328,)
# (6315328,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9351168, 2)
# (9351168, 2)
# (9351168, 2)
# (9354816,)
# (9354816,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8443712, 2)
# (8443712, 2)
# (8443712, 2)
# (8446784,)
# (8446784,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (3252224, 2)
# (3252224, 2)
# (3252224, 2)
# (3256256,)
# (3256256,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (11650696, 2)
# (11650696, 2)
# (11650696, 2)
# (11653824,)
# (11653824,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (13864448, 2)
# (13864448, 2)
# (13864448, 2)
# (13867200,)
# (13867200,)
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# (10422594, 2)
# (10422594, 2)
# (10422594, 2)
# (10584896,)
# (10584896,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (2667904, 2)
# (2667904, 2)
# (2667904, 2)
# (2671296,)
# (2671296,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (5840704, 2)
# (5840704, 2)
# (5840704, 2)
# (5843776,)
# (5843776,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9799552, 2)
# (9799552, 2)
# (9799552, 2)
# (9803584,)
# (9803584,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (13047808, 2)
# (13047808, 2)
# (13047808, 2)
# (13051200,)
# (13051200,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (11489152, 2)
# (11489152, 2)
# (11489152, 2)
# (11493184,)
# (11493184,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (7381440, 2)
# (7381440, 2)
# (7381440, 2)
# (7384512,)
# (7384512,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (3730816, 2)
# (3730816, 2)
# (3730816, 2)
# (3733824,)
# (3733824,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (13690304, 2)
# (13690304, 2)
# (13690304, 2)
# (13693632,)
# (13693632,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (7620608, 2)
# (7620608, 2)
# (7620608, 2)
# (7623872,)
# (7623872,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8500224, 2)
# (8500224, 2)
# (8500224, 2)
# (8502272,)
# (8502272,)
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# (5865300, 2)
# (5865300, 2)
# (5865300, 2)
# (5866176,)
# (5866176,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9395328, 2)
# (9395328, 2)
# (9395328, 2)
# (9398976,)
# (9398976,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9315648, 2)
# (9315648, 2)
# (9315648, 2)
# (9318720,)
# (9318720,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10428096, 2)
# (10428096, 2)
# (10428096, 2)
# (10430656,)
# (10430656,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (11513856, 2)
# (11513856, 2)
# (11513856, 2)
# (11515200,)
# (11515200,)
# Unprocessed audio URL
# Unprocessed audio URL
# Processed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# Processed audio URL
# (10265600, 2)
# (10265600, 2)
# (10265600, 2)
# (10584896,)
# (10584896,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (11208128, 2)
# (11208128, 2)
# (11208128, 2)
# (11211072,)
# (11211072,)
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# (9545445, 2)
# (9545445, 2)
# (9545445, 2)
# (9702720,)
# (9702720,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (12170240, 2)
# (12170240, 2)
# (12170240, 2)
# (12173760,)
# (12173760,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (7736320, 2)
# (7736320, 2)
# (7736320, 2)
# (7740352,)
# (7740352,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10453888, 2)
# (10453888, 2)
# (10453888, 2)
# (10456640,)
# (10456640,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (15184448, 2)
# (15184448, 2)
# (15184448, 2)
# (15187392,)
# (15187392,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (2807744, 2)
# (2807744, 2)
# (2807744, 2)
# (2810816,)
# (2810816,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (2916928, 2)
# (2916928, 2)
# (2916928, 2)
# (2920000,)
# (2920000,)
# Unprocessed audio URL
# Processed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# Processed audio URL
# Unprocessed audio URL
# (15742272, 2)
# (15742272, 2)
# (15742272, 2)
# (15745472,)
# (15745472,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (11908224, 2)
# (11908224, 2)
# (11908224, 2)
# (11908224,)
# (11908224,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (12731072, 2)
# (12731072, 2)
# (12731072, 2)
# (12733632,)
# (12733632,)
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# (10584000, 2)
# (10584000, 2)
# (10584000, 2)
# (10584896,)
# (10584896,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9074112, 2)
# (9074112, 2)
# (9074112, 2)
# (9077184,)
# (9077184,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9955328, 2)
# (9955328, 2)
# (9955328, 2)
# (9958976,)
# (9958976,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (11061248, 2)
# (11061248, 2)
# (11061248, 2)
# (11062848,)
# (11062848,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (7763776, 2)
# (7763776, 2)
# (7763776, 2)
# (7767872,)
# (7767872,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8348672, 2)
# (8348672, 2)
# (8348672, 2)
# (8352320,)
# (8352320,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (5735424, 2)
# (5735424, 2)
# (5735424, 2)
# (5738944,)
# (5738944,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (6773632, 2)
# (6773632, 2)
# (6773632, 2)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (6814976, 2)
# (6814976, 2)
# (6814976, 2)
# (6818112,)
# (6818112,)
# Unprocessed audio URL
# Processed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# Processed audio URL
# Unprocessed audio URL
# (19713344, 2)
# (19713344, 2)
# (19713344, 2)
# (19716928,)
# (19716928,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (7430007, 2)
# (7430007, 2)
# (7430007, 2)
# (7433024,)
# (7433024,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9517056, 2)
# (9517056, 2)
# (9517056, 2)
# (9520320,)
# (9520320,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (12787712, 2)
# (12787712, 2)
# (12787712, 2)
# (12791360,)
# (12791360,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (12630464, 2)
# (12630464, 2)
# (12630464, 2)
# (12632064,)
# (12632064,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (13236224, 2)
# (13236224, 2)
# (13236224, 2)
# (13240256,)
# (13240256,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10878976, 2)
# (10878976, 2)
# (10878976, 2)
# (10882624,)
# (10882624,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (6084096, 2)
# (6084096, 2)
# (6084096, 2)
# (6087232,)
# (6087232,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8169472, 2)
# (8169472, 2)
# (8169472, 2)
# (8173120,)
# (8173120,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (1011712, 2)
# (1011712, 2)
# (1011712, 2)
# (1014976,)
# (1014976,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10491904, 2)
# (10491904, 2)
# (10491904, 2)
# (10491904,)
# (10491904,)
# Unprocessed audio URL
# Unprocessed audio URL
# Processed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# Processed audio URL
# (8820000, 2)
# (8820000, 2)
# (8820000, 2)
# (9526464,)
# (9526464,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (7585792, 2)
# (7585792, 2)
# (7585792, 2)
# (7589440,)
# (7589440,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9418368, 2)
# (9418368, 2)
# (9418368, 2)
# (9468864,)
# (9468864,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (7464448, 2)
# (7464448, 2)
# (7464448, 2)
# (7520064,)
# (7520064,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (11245568, 2)
# (11245568, 2)
# (11245568, 2)
# (11248832,)
# (11248832,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9884672, 2)
# (9884672, 2)
# (9884672, 2)
# (9886720,)
# (9886720,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9775104, 2)
# (9775104, 2)
# (9775104, 2)
# (9778624,)
# (9778624,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10981952, 2)
# (10981952, 2)
# (10981952, 2)
# (10985024,)
# (10985024,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8908224, 2)
# (8908224, 2)
# (8908224, 2)
# (9023936,)
# (9023936,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (7585792, 2)
# (7585792, 2)
# (7585792, 2)
# (7589440,)
# (7589440,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8025744, 2)
# (8025744, 2)
# (8025744, 2)
# (8379072,)
# (8379072,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10982400, 2)
# (10982400, 2)
# (10982400, 2)
# (10986176,)
# (10986176,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (17423296, 2)
# (17423296, 2)
# (17423296, 2)
# (17426368,)
# (17426368,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (11582464, 2)
# (11582464, 2)
# (11582464, 2)
# (11586368,)
# (11586368,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (11318272, 2)
# (11318272, 2)
# (11318272, 2)
# (11321536,)
# (11321536,)
# Unprocessed audio URL
# Unprocessed audio URL
# Processed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# Processed audio URL
# (17199000, 2)
# (17199000, 2)
# (17199000, 2)
# (17243200,)
# (17243200,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (13166400, 2)
# (13166400, 2)
# (13166400, 2)
# (13169472,)
# (13169472,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (12013056, 2)
# (12013056, 2)
# (12013056, 2)
# (12017344,)
# (12017344,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (5800960, 2)
# (5800960, 2)
# (5800960, 2)
# (5804736,)
# (5804736,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10764160, 2)
# (10764160, 2)
# (10764160, 2)
# (10767808,)
# (10767808,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (11837696, 2)
# (11837696, 2)
# (11837696, 2)
# (12206656,)
# (12206656,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (11405248, 2)
# (11405248, 2)
# (11405248, 2)
# (11408320,)
# (11408320,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (13640704, 2)
# (13640704, 2)
# (13640704, 2)
# (13644096,)
# (13644096,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8225792, 2)
# (8225792, 2)
# (8225792, 2)
# (8229184,)
# (8229184,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10575936, 2)
# (10575936, 2)
# (10575936, 2)
# (10579008,)
# (10579008,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (7030336, 2)
# (7030336, 2)
# (7030336, 2)
# (7033408,)
# (7033408,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9042944, 2)
# (9042944, 2)
# (9042944, 2)
# (9046720,)
# (9046720,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (7216576, 2)
# (7216576, 2)
# (7216576, 2)
# (7219648,)
# (7219648,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8643008, 2)
# (8643008, 2)
# (8643008, 2)
# (8647104,)
# (8647104,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (22958079, 2)
# (22958079, 2)
# (22958079, 2)
# (22961216,)
# (22961216,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (7948416, 2)
# (7948416, 2)
# (7948416, 2)
# (7951552,)
# (7951552,)
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# 'Warning: Sample rates unequal'
# (11237739, 2)
# (11237739, 2)
# (11237739, 2)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (7658816, 2)
# (7658816, 2)
# (7658816, 2)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10017792, 2)
# (10017792, 2)
# (10017792, 2)
# (10020928,)
# (10020928,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10098688, 2)
# (10098688, 2)
# (10098688, 2)
# (10102592,)
# (10102592,)
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# (5865300, 2)
# (5865300, 2)
# (5865300, 2)
# (5866048,)
# (5866048,)
# Unprocessed audio URL
# Processed audio URL
# Processed audio URL
# Unprocessed audio URL
# Processed audio URL
# Processed audio URL
# (9310442, 2)
# (9310442, 2)
# (9310442, 2)
# (9310442,)
# (9310442,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (7214912, 2)
# (7214912, 2)
# (7214912, 2)
# (7217984,)
# (7217984,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8480640, 2)
# (8480640, 2)
# (8480640, 2)
# (8482816,)
# (8482816,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8114176, 2)
# (8114176, 2)
# (8114176, 2)
# (8116288,)
# (8116288,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (11554944, 2)
# (11554944, 2)
# (11554944, 2)
# (11557952,)
# (11557952,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (7824576, 2)
# (7824576, 2)
# (7824576, 2)
# (7827648,)
# (7827648,)
# Unprocessed audio URL
# Processed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# Processed audio URL
# Unprocessed audio URL
# (6072384, 2)
# (6072384, 2)
# (6072384, 2)
# (6075456,)
# (6075456,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8275328, 2)
# (8275328, 2)
# (8275328, 2)
# (8278848,)
# (8278848,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8842240, 2)
# (8842240, 2)
# (8842240, 2)
# (8845376,)
# (8845376,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8138260, 2)
# (8138260, 2)
# (8138260, 2)
# (8141120,)
# (8141120,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (12278720, 2)
# (12278720, 2)
# (12278720, 2)
# (12281920,)
# (12281920,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (11239424, 2)
# (11239424, 2)
# (11239424, 2)
# (11242816,)
# (11242816,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8561856, 2)
# (8561856, 2)
# (8561856, 2)
# (8565056,)
# (8565056,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10231808, 2)
# (10231808, 2)
# (10231808, 2)
# (10234944,)
# (10234944,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (2753600, 2)
# (2753600, 2)
# (2753600, 2)
# (2756672,)
# (2756672,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (6844672, 2)
# (6844672, 2)
# (6844672, 2)
# (6847936,)
# (6847936,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (7101440, 2)
# (7101440, 2)
# (7101440, 2)
# (7105344,)
# (7105344,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9790464, 2)
# (9790464, 2)
# (9790464, 2)
# (9794368,)
# (9794368,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (10632192, 2)
# (10632192, 2)
# (10632192, 2)
# (10636224,)
# (10636224,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (7350400, 2)
# (7350400, 2)
# (7350400, 2)
# (7354048,)
# (7354048,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8181632, 2)
# (8181632, 2)
# (8181632, 2)
# (8185792,)
# (8185792,)
# Unprocessed audio URL
# Processed audio URL
# Processed audio URL
# Unprocessed audio URL
# Processed audio URL
# Processed audio URL
# (9343040, 2)
# (9343040, 2)
# (9343040, 2)
# (9347008,)
# (9347008,)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (9465984, 2)
# (9465984, 2)
# (9465984, 2)
# (9470016,)
# (9470016,)

# %%
print(len(good_rmse))
print(len(bad_rmse))
print(len(med_rmse))
print(len(rmse))
print(len(unproc_rmse))
print(len(proc_rmse))
print(count)
# Out:
# 16
# 8
# 5
# 291
# 266
# 25
# 2

# %%
good_proc_id = good_proc_id[:5]
bad_proc_id = bad_proc_id[:5]
med_proc_id = med_proc_id[:5]
good_rmse = good_rmse[:5]
bad_rmse = bad_rmse[:5]
med_rmse = med_rmse[:5]

# %% [markdown]
# Given a fixed number of published tracks, here we gather all the mixes that have multiple mixing coefficients. They are stored in the variable titled 'proc_id' (which stands for processed ids). 'proc_id' is a list of mixes that have multiple mixing coefficients, and each of these mixes is identified by a tuple comprising its post ID and song ID.

# %%
mult_vol_proc_id = get_processed_audio_ids_multiple_volumes(num_pub_track)
pprint.pprint(mult_vol_proc_id)

# %% [markdown]
# Each mix is individually parsed and the tuple is deconstructed and stored as separate variables titled 'post_id' and 'song_id'. These variables are then used to call the 'get_mixing_coeff' function, which returns all the data required to compute the estimated mix. We store each mixing coefficient in separate variables.<br>
# The variable 'ogg_paths' stores the URL of where the files are stored on the Bandhub server. We used this variable to extract the file names of each of the constituent published tracks.<br>
# Finally, we used the song ID to fetch the video URL and download it to the current working directory. Later, we use this file to extract the mixed audio, which we refer to as *bandhub_mix*.<br>
# At this point, for a given mix, we have all the published tracks and the mixed video saved locally. We also have the mixing coefficients required to compute the estimated mix.

# %%
for i in range(len(good_proc_id)):
    track_filenames = []
    proc_status = 0
    
    post_id = good_proc_id[i][0]
    song_id = good_proc_id[i][1]
    
    volume_settings, volume_channels, ogg_paths, start_times = get_mixing_coeff(num_pub_track, song_id, post_id, proc_status)
    if len(ogg_paths) is 0:
        proc_status = 1
        volume_settings, volume_channels, ogg_paths, start_times = get_mixing_coeff(num_pub_track, song_id, post_id, proc_status)
        
    if len(ogg_paths) is not num_pub_track:
            continue
    else:
        for j in range(num_pub_track):
            download_track(ogg_paths[j])
            track_filenames.append(get_filename(ogg_paths[j]))

    for i in range(num_pub_track):
        download_track(ogg_paths[i])
        track_filenames.append(get_filename(ogg_paths[i]))

    pointer = vidCol.find({'songId': song_id})
    for songdocs in pointer:
        bandhub_mix = songdocs['oggMergedVideoUrl']

    download_track(bandhub_mix)
    
    ogg_tracks, mixsr = match_track_lengths(num_pub_track,track_filenames,start_times)
    if mixsr is -1:
        continue
    else:
        volume_settings, volume_channels, ogg_paths, start_times = get_mixing_coeff(num_pub_track, song_id, post_id, proc_status)
        mix_ogg = compute_estimated_mix(num_pub_track, volume_settings, ogg_tracks, mixsr)
        sf.write('mixed_'+str(song_id)+'.wav', mix_ogg / np.max(np.abs(mix_ogg)), mixsr)
        mix_ogg_ch = compute_estimated_mix(num_pub_track, volume_channels, ogg_tracks, mixsr)
        sf.write('mixed_ch'+str(song_id)+'.wav', mix_ogg_ch / np.max(np.abs(mix_ogg_ch)), mixsr)
        for premix in os.listdir('.'):
            if fnmatch.fnmatch(premix, 'f-*'):
                rename_cmd = ['mv', premix, 'premix.ogg']
                sr = subprocess.call(rename_cmd)
                if sr is 0:
                    print('Rename success!')
                    convert_cmd = ['ffmpeg', '-i', 'premix.ogg', '-vsync', '1', '-async', '1', '-vn', 'premix_'+str(song_id)+'.wav']
                    sc = subprocess.call(convert_cmd)
                    if sc is 0:
                        print('Audio strip success!')
                    else:
                        print('ERROR: Audio strip failed!')
                else:
                    print('ERROR: Rename failed!')
# Out:
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# (9878400, 2)
# (9878400, 2)
# (9878400, 2)
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Rename success!
# Audio strip success!
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# (7761600, 2)
# (7761600, 2)
# (7761600, 2)
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Rename success!
# Audio strip success!
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# (8305343, 2)
# (8305343, 2)
# (8305343, 2)
# Unprocessed audio URL
# Unprocessed audio URL
# Unprocessed audio URL
# Rename success!
# Audio strip success!
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# (8467200, 2)
# (8467200, 2)
# (8467200, 2)
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Rename success!
# Audio strip success!
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Processed audio URL
# (9172800, 2)
# (9172800, 2)
# (9172800, 2)
# Processed audio URL
# Processed audio URL
# Processed audio URL
# Rename success!
# Audio strip success!

# %% [markdown]
# Now that we have all the data and the required mixing coefficients, we can compute both the estimated mixes (one using the track volumes found in the settings dictionary, and the other using those found in the audioChannels list nested within the settings field). However, we must first ensure that all the tracks are of equal duration. So we call the match_track_lengths function, then compute the estimated mixes, and finally write those out as wav files to the current working directory.
# Next, we strip the audio from the mixed video download earlier and write that out as well. This step, however, introduces a slight offset in the mixed audio.
# With the completion of this step, we have all the audio files required to analyze and compare the performance of the mixing coefficients.

# %% [markdown]
# As mentioned earlier, the audio stripping process introduces a slight offset in the mixed audio. So after reading in the bandhub_mix audio file titled 'premix.wav', we compute and compensate for this offset using both the estimated mixes and the compute_offset_and_shift function. Finally, we plot the difference spectrograms and calculate the root mean square error (rmse) between each of the estimated mixes and the bandhub mix. The estimated mix with the lower rmse is, therefore, more similar to the bandhub mix. <br>
# Executing this script over all the mixes with multiple mixing coefficients will prove which mixing coefficients to consider in the case that multiple mixing coefficients are present.

# %%
path = '/scratch/rrs432/tracks'
os.chdir(path)
# !ls
# Out:
# 086eafd1-ac36-4d28-ae34-1a65c2e90cfe.ogg
# 18b86588-792e-44ae-9064-dcf073e6102c.ogg
# 2e2a3326-5047-43af-89cf-aa9332233a0f-0-0.ogg
# 44a84e8d-b205-441b-8385-a346601fd56a.ogg
# 49365c12-70a3-4969-9e3b-1ff38853ee69.ogg
# 560eca28-de61-40c5-805f-235c75a1af74.ogg
# 5fa05a06-3923-403f-98d0-8dc0681e7361-0-0.ogg
# 66592e9f-2f02-4673-af23-091ad0b5e647.ogg
# 67c9cbb2-8351-465f-898c-6596ed0264fb.ogg
# 6a55556c-318c-4672-a33f-db73ca248735.ogg
# 6b2f79aa-0968-44d7-87e8-b4368c6b91c3.ogg
# 93020cfd-9ffa-4e42-afbc-03782a621e4f.ogg
# 9efbcb7a-b76d-4922-b38c-d9624a4eb3a0-0.ogg
# c55f2fd7-f324-404a-bec4-e180adcad111.ogg
# d359e6f4-4efc-44cb-87c3-b2d9ccb75290.ogg
# mixed_53b68334fbc043c6060015c7.wav
# mixed_53fc47788a1fbced64347627.wav
# mixed_54035c0a3c77863321d64b26.wav
# mixed_5403f3db21715eed7bc3b259.wav
# mixed_544d6238288e1c075931a684.wav
# mixed_ch53b68334fbc043c6060015c7.wav
# mixed_ch53fc47788a1fbced64347627.wav
# mixed_ch54035c0a3c77863321d64b26.wav
# mixed_ch5403f3db21715eed7bc3b259.wav
# mixed_ch544d6238288e1c075931a684.wav
# plots
# premix_53b68334fbc043c6060015c7.wav
# premix_53fc47788a1fbced64347627.wav
# premix_54035c0a3c77863321d64b26.wav
# premix_5403f3db21715eed7bc3b259.wav
# premix_544d6238288e1c075931a684.wav
# premix.ogg
# testcases

# %%
for i in range(len(good_proc_id)):
    
    song_id = good_proc_id[i][1]
    bandhub_mix, sr = sf.read('premix_'+song_id+'.wav')
    estimated_mix, sr = sf.read('mixed_'+song_id+'.wav')
    estimated_mix_spec,bandhub_mix_spec = compute_offset_and_shift(estimated_mix, bandhub_mix, sr)
    root_mean_sq_error = plot_diff_spectrogram(estimated_mix_spec,bandhub_mix_spec)
    print('RMSE for estimated mix using volume from settings: '+str(root_mean_sq_error))
    estimated_mix_ch, sr = sf.read('mixed_ch_'+song_id+'.wav')
    estimated_mix_ch_spec,bandhub_mix_spec = compute_offset_and_shift(estimated_mix_ch, bandhub_mix, sr)
    root_mean_sq_error = plot_diff_spectrogram(estimated_mix_ch_spec,bandhub_mix_spec)
    print('RMSE for estimated mix using volume from channels: '+str(root_mean_sq_error))
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-22-c2f2b4964e9a> in <module>()
# ----> 1 for i in range(len(good_proc_id)):
#       2
#       3     song_id = good_proc_id[i][1]
#       4     bandhub_mix, sr = sf.read('premix_'+song_id+'.wav')
#       5     estimated_mix, sr = sf.read('mixed_'+song_id+'.wav')
#
# NameError: name 'good_proc_id' is not defined

# %%
bandhub_mix, sr = sf.read('premix.wav')

# %%
estimated_mix, sr = sf.read('mixed.wav')
estimated_mix_spec,bandhub_mix_spec = compute_offset_and_shift(estimated_mix, bandhub_mix, sr)
root_mean_sq_error = plot_diff_spectrogram(estimated_mix_spec,bandhub_mix_spec)
print('RMSE for estimated mix using volume from settings: '+str(root_mean_sq_error))

# %%
estimated_mix_ch, sr = sf.read('mixed_ch.wav')
estimated_mix_ch_spec,bandhub_mix_spec = compute_offset_and_shift(estimated_mix_ch, bandhub_mix, sr)
root_mean_sq_error = plot_diff_spectrogram(estimated_mix_ch_spec,bandhub_mix_spec)
print('RMSE for estimated mix using volume from channels: '+str(root_mean_sq_error))

# %%
path = '/scratch/rrs432/tracks/testcases'
os.chdir(path)

# %% [markdown]
# ## RMSE Distributions
# <center> <h3>RMSE Distribution of 500 3-published-track mixes</h3> </center>

# %%
df = pd.DataFrame(rmse)
ax = df[(df<250) & (df >= 0)].plot(kind='hist',grid=True,figsize=(10,10),bins = 250,title='RMSE Distribution of 500 3-published-track mixes')
ax.set(xlabel="Root mean square error", ylabel="Number of mixes")
# Out:
# [Text(0,0.5,u'Number of mixes'), Text(0.5,0,u'Root mean square error')]

# %% [markdown]
# <center> <h3>RMSE Distribution of 267/500 3-published-unprocessed-track mixes</h3> </center>

# %%
df = pd.DataFrame(unproc_rmse)
ax = df[(df<250) & (df >= 0)].plot(kind='hist',grid=True,figsize=(10,10),bins = 250,title='RMSE Distribution of 500 3-published-track mixes')
ax.set(xlabel="Root mean square error", ylabel="Number of mixes")
# Out:
# [Text(0,0.5,u'Number of mixes'), Text(0.5,0,u'Root mean square error')]

# %% [markdown]
# Note: The below distribution plot shows the RMSE of mixes which have atleast 1 processed audio track in mixes with 3 published tracks.
# Even though the number of such mixes is a small fraction, the RMSE is considerably lower than mixes with all unprocessed track mixes (as shown in the plot above)

# %% [markdown]
# <center> <h3>RMSE Distribution of 24/500 3-published-processed-track mixes</h3> </center>

# %%
df = pd.DataFrame(proc_rmse)
ax = df[(df<250) & (df >= 0)].plot(kind='hist',grid=True,figsize=(10,10),bins = 250,title='RMSE Distribution of 500 3-published-track mixes')
ax.set(xlabel="Root mean square error", ylabel="Number of mixes")
# Out:
# [Text(0,0.5,u'Number of mixes'), Text(0.5,0,u'Root mean square error')]

# %% [markdown]
# ## RMSE Distributions
# <center> <h3>RMSE Distribution of 500 3-published-track mixes</h3> </center>
# ![RMSE Distribution of 500 3-published-track mixes](pnt3-500.png "RMSE Distribution of 500 3-published-track mixes")
# <center> <h3>RMSE Distribution of 267/500 3-published-unprocessed-track mixes</h3> </center>
# ![RMSE Distribution of 500 3-published-unprocessed-track mixes](unproc267-305.png "RMSE Distribution of 500 3-published-unprocessed-track mixes")
# Note: The below distribution plot shows the RMSE of mixes which have atleast 1 processed audio track in mixes with 3 published tracks.
# Even though the number of such mixes is a small fraction, the RMSE is considerably lower than mixes with all unprocessed track mixes (as shown in the plot above)
# <center> <h3>RMSE Distribution of 24/500 3-published-processed-track mixes</h3> </center>
# ![RMSE Distribution of 500 atleast 1 processed track in 3-published-track mixes](proc24-305.png "RMSE Distribution of 500 atleast 1 processed track in 3-published-track mixes")
#
# <center> <h3>RMSE Distribution of 500 5-published-track mixes</h3> </center>
# ![RMSE Distribution of 500 5-published-track mixes](pnt5-500.png "RMSE Distribution of 500 5-published-track mixes")
# <center> <h3>RMSE Distribution of 176/500 5-published-unprocessed-track mixes</h3> </center>
# ![RMSE Distribution of 500 3-published-unprocessed-track mixes](unproc176-400.png "RMSE Distribution of 500 5-published-unprocessed-track mixes")
# <center> <h3>RMSE Distribution of 91/500 5-published-processed-track mixes</h3> </center>
# ![RMSE Distribution of 500 atleast 1 processed track in 5-published-track mixes](proc91-400.png "RMSE Distribution of 500 atleast 1 processed track in 5-published-track mixes")

# %% [markdown]
# ## Difference Spectrogram Plots
# <center> <h3>Plots of 5 3-published-track mixes with RMSE less than 2</h3> </center>
# <center> <h5>RMSE = 0.17, Processed audio tracks</h5> </center>
# ![RMSE = 0.17, Processed audio tracks](g1.png "RMSE = 0.17, Processed audio tracks")

# %%
#BandHub Mix
ipd.Audio('g1b.wav')

# %%
#Estimated Mix
ipd.Audio('g1e.wav')

# %% [markdown]
# <center> <h5>RMSE = 0.12, Processed audio tracks</h5> </center>
# ![RMSE = 0.12, Processed audio tracks](g2.png "RMSE = 0.12, Processed audio tracks")

# %%
#BandHub Mix
ipd.Audio('g2b.wav')

# %%
#Estimated Mix
ipd.Audio('g2e.wav')

# %% [markdown]
# <center> <h5>RMSE = 0.54, Unprocessed audio tracks</h5> </center>
# ![RMSE = 0.54, Unprocessed audio tracks](g3.png "RMSE = 0.54, Unprocessed audio tracks")

# %%
#BandHub Mix
ipd.Audio('g3b.wav')

# %%
#Estimated Mix
ipd.Audio('g3e.wav')

# %% [markdown]
# <center> <h5>RMSE = 0.2, Processed audio tracks</h5> </center>
# ![RMSE = 0.2, Processed audio tracks](g4.png "RMSE = 0.2, Processed audio tracks")

# %%
#BandHub Mix
ipd.Audio('g4b.wav')

# %%
#Estimated Mix
ipd.Audio('g4e.wav')

# %% [markdown]
# <center> <h5>RMSE = 1.15, Processed audio tracks</h5> </center>
# ![RMSE = 1.15, Processed audio tracks](g5.png "RMSE = 1.15, Processed audio tracks")

# %%
#BandHub Mix
ipd.Audio('g5b.wav')

# %%
#Estimated Mix
ipd.Audio('g5e.wav')

# %% [markdown]
# <center> <h3>Plots of 5 3-published-track mixes with RMSE in the range 75-80</h3> </center>
# <center> <h5>RMSE = 76.04, Unprocessed audio tracks</h5> </center>
# ![RMSE = 76.04, Unprocessed audio tracks](m1.png "RMSE = 76.04, Unprocessed audio tracks")

# %%
#BandHub Mix
ipd.Audio('m1b.wav')

# %%
#Estimated Mix
ipd.Audio('m1e.wav')

# %% [markdown]
# <center> <h5>RMSE = 76.21, Unprocessed audio tracks</h5> </center>
# ![RMSE = 76.21, Unprocessed audio tracks](m2.png "RMSE = 76.21, Unprocessed audio tracks")

# %%
#BandHub Mix
ipd.Audio('m2b.wav')

# %%
#Estimated Mix
ipd.Audio('m2e.wav')

# %% [markdown]
# <center> <h5>RMSE = 78.8, Unprocessed audio tracks</h5> </center>
# ![RMSE = 78.8, Unprocessed audio tracks](m3.png "RMSE = 78.8, Unprocessed audio tracks")

# %%
#BandHub Mix
ipd.Audio('m3b.wav')

# %%
#Estimated Mix
ipd.Audio('m3e.wav')

# %% [markdown]
# <center> <h5>RMSE = 76.12, Unprocessed audio tracks</h5> </center>
# ![RMSE = 76.12, Unprocessed audio tracks](m4.png "RMSE = 76.12, Unprocessed audio tracks")

# %%
#BandHub Mix
ipd.Audio('m4b.wav')

# %%
#Estimated Mix
ipd.Audio('m4e.wav')

# %% [markdown]
# <center> <h5>RMSE = 75.91, Unprocessed audio tracks</h5> </center>
# ![RMSE = 75.91, Unprocessed audio tracks](m5.png "RMSE = 75.91, Unprocessed audio tracks")

# %%
#BandHub Mix
ipd.Audio('m5b.wav')

# %%
#Estimated Mix
ipd.Audio('m5e.wav')

# %% [markdown]
# <center> <h3>Plots of 5 3-published-track mixes with RMSE greater than 150</h3> </center>
# <center> <h5>RMSE = 248.05, Unprocessed audio tracks</h5> </center>
# ![RMSE = 248.05, Unprocessed audio tracks](b1.png "RMSE = 248.05, Unprocessed audio tracks")

# %%
#BandHub Mix
ipd.Audio('b1b.wav')

# %%
#Estimated Mix
ipd.Audio('b1e.wav')

# %% [markdown]
# In the above example, we can see that the bandhub mix has only the electric guitar track. None of the other published tracks are in the final bandhub mix. Whereas, the estimated mix is complete with all the published tracks. The associated mixing coefficients (start times and volume) are also accurate.

# %% [markdown]
# <center> <h5>RMSE = 204.46, Unprocessed audio tracks</h5> </center>
# ![RMSE = 204.46, Unprocessed audio tracks](b2.png "RMSE = 204.46, Unprocessed audio tracks")

# %%
#BandHub Mix
ipd.Audio('b2b.wav')

# %%
#Estimated Mix
ipd.Audio('b2e.wav')

# %% [markdown]
# The bandhub mix in this case is missing a lot of high frequency information in the drum track. The drums sound exremely dull and muted. Even the bassline is quite unclear, and the mix seems to go out of time a lot. The estimated mix is a lot brighter and fuller.

# %% [markdown]
# <center> <h5>RMSE = 166.1, Unprocessed audio tracks</h5> </center>
# ![RMSE = 166.1, Unprocessed audio tracks](b3.png "RMSE = 166.1, Unprocessed audio tracks")

# %%
#BandHub Mix
ipd.Audio('b3b.wav')

# %%
#Estimated Mix
ipd.Audio('b3e.wav')

# %% [markdown]
# The bandhub mix is missing some published tracks (only vocals and acoustic guitar present). The estimated mix comprises the bass, drums, and processed vocals and guitar. It's almost like the bandhub mix is an unplugged version of the estimated mix.

# %% [markdown]
# <center> <h5>RMSE = 161.03, Unprocessed audio tracks</h5> </center>
# ![RMSE = 161.03, Unprocessed audio tracks](b4.png "RMSE = 161.03, Unprocessed audio tracks")

# %%
#BandHub Mix
ipd.Audio('b4b.wav')

# %%
#Estimated Mix
ipd.Audio('b4e.wav')

# %% [markdown]
# The Bandhub mix comprises only the vocals and bass. The estimated mix comprises all published tracks.

# %% [markdown]
# <center> <h5>RMSE = 164.6, Unprocessed audio tracks</h5> </center>
# ![RMSE = 164.6, Unprocessed audio tracks](b5.png "RMSE = 164.6, Unprocessed audio tracks")

# %%
#BandHub Mix
ipd.Audio('b5b.wav')

# %%
#Estimated Mix
ipd.Audio('b5e.wav')

# %% [markdown]
# This is a case where an incorrect start time for the drum track has caused a severe misalignment of the published tracks in the estimated mix. In the bandhub mix, we can hear the drums come in slightly after the guitar. Whereas, in the estimated mix, both tracks start simulaneously causing the misalignment.

# %% [markdown]
# We can, therefore, safely conclude that remixing the published tracks using the mixing coefficients is a far better approach than using bandhubs mixes. This will not only save us storage space, but will also produce more reliable, error-free data.
