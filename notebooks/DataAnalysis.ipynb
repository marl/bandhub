# %%
import pymongo
import pandas as pd
#from pandas import Series
import numpy as np
#import matplotlib.pyplot as plt
#from collections import Counter
#from bson.objectid import ObjectId
import pprint

# %%
client = pymongo.MongoClient('localhost',27017)
#client = pymongo.MongoClient('localhost',32768)
db = client.bandhub

# %%
songCol = db.get_collection('songsStream')
vidCol = db.get_collection('mergedVideos')
trackCol = db.get_collection('tracksStream')
postCol = db.get_collection('posts')
[songCol.count(), vidCol.count(), trackCol.count(), postCol.count()]
# Out:
# ServerSelectionTimeoutErrorTraceback (most recent call last)
# <ipython-input-6-273244569630> in <module>()
#       3 trackCol = db.get_collection('tracksStream')
#       4 postCol = db.get_collection('posts')
# ----> 5 [songCol.count(), vidCol.count(), trackCol.count(), postCol.count()]
#
# /home/rrs432/miniconda2/envs/bandhub/lib/python2.7/site-packages/pymongo/collection.pyc in count(self, filter, **kwargs)
#    1352         collation = validate_collation_or_none(kwargs.pop('collation', None))
#    1353         cmd.update(kwargs)
# -> 1354         return self._count(cmd, collation)
#    1355
#    1356     def create_indexes(self, indexes):
#
# /home/rrs432/miniconda2/envs/bandhub/lib/python2.7/site-packages/pymongo/collection.pyc in _count(self, cmd, collation)
#    1302     def _count(self, cmd, collation=None):
#    1303         """Internal count helper."""
# -> 1304         with self._socket_for_reads() as (sock_info, slave_ok):
#    1305             res = self._command(
#    1306                 sock_info, cmd, slave_ok,
#
# /home/rrs432/miniconda2/envs/bandhub/lib/python2.7/contextlib.pyc in __enter__(self)
#      15     def __enter__(self):
#      16         try:
# ---> 17             return self.gen.next()
#      18         except StopIteration:
#      19             raise RuntimeError("generator didn't yield")
#
# /home/rrs432/miniconda2/envs/bandhub/lib/python2.7/site-packages/pymongo/mongo_client.pyc in _socket_for_reads(self, read_preference)
#     857         topology = self._get_topology()
#     858         single = topology.description.topology_type == TOPOLOGY_TYPE.Single
# --> 859         with self._get_socket(read_preference) as sock_info:
#     860             slave_ok = (single and not sock_info.is_mongos) or (
#     861                 preference != ReadPreference.PRIMARY)
#
# /home/rrs432/miniconda2/envs/bandhub/lib/python2.7/contextlib.pyc in __enter__(self)
#      15     def __enter__(self):
#      16         try:
# ---> 17             return self.gen.next()
#      18         except StopIteration:
#      19             raise RuntimeError("generator didn't yield")
#
# /home/rrs432/miniconda2/envs/bandhub/lib/python2.7/site-packages/pymongo/mongo_client.pyc in _get_socket(self, selector)
#     821     @contextlib.contextmanager
#     822     def _get_socket(self, selector):
# --> 823         server = self._get_topology().select_server(selector)
#     824         try:
#     825             with server.get_socket(self.__all_credentials) as sock_info:
#
# /home/rrs432/miniconda2/envs/bandhub/lib/python2.7/site-packages/pymongo/topology.pyc in select_server(self, selector, server_selection_timeout, address)
#     212         return random.choice(self.select_servers(selector,
#     213                                                  server_selection_timeout,
# --> 214                                                  address))
#     215
#     216     def select_server_by_address(self, address,
#
# /home/rrs432/miniconda2/envs/bandhub/lib/python2.7/site-packages/pymongo/topology.pyc in select_servers(self, selector, server_selection_timeout, address)
#     187                 if server_timeout == 0 or now > end_time:
#     188                     raise ServerSelectionTimeoutError(
# --> 189                         self._error_message(selector))
#     190
#     191                 self._ensure_opened()
#
# ServerSelectionTimeoutError: localhost:27017: [Errno 111] Connection refused

# %%
pubData = []

# %%
pointer = songCol.find({'access' : 1})

# %%
for songDoc in pointer:
    songId = songDoc['_id']
    postId = postCol.find({'objectId' : songId})
    vidId = vidCol.find({'songId': songId})

# %%
pprint.pprint(postId.count())
# Out:
# AutoReconnectTraceback (most recent call last)
# <ipython-input-35-14d64904c08f> in <module>()
# ----> 1 pprint.pprint(postId.count())
#
# /home/rrs432/miniconda2/envs/bandhub/lib/python2.7/site-packages/pymongo/cursor.pyc in count(self, with_limit_and_skip)
#     709                 cmd["skip"] = self.__skip
#     710
# --> 711         return self.__collection._count(cmd, self.__collation)
#     712
#     713     def distinct(self, key):
#
# /home/rrs432/miniconda2/envs/bandhub/lib/python2.7/site-packages/pymongo/collection.pyc in _count(self, cmd, collation)
#    1308                 codec_options=self.__write_response_codec_options,
#    1309                 read_concern=self.read_concern,
# -> 1310                 collation=collation)
#    1311         if res.get("errmsg", "") == "ns missing":
#    1312             return 0
#
# /home/rrs432/miniconda2/envs/bandhub/lib/python2.7/site-packages/pymongo/collection.pyc in _command(self, sock_info, command, slave_ok, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation)
#     230             write_concern=write_concern,
#     231             parse_write_concern_error=parse_write_concern_error,
# --> 232             collation=collation)
#     233
#     234     def __create(self, options, collation):
#
# /home/rrs432/miniconda2/envs/bandhub/lib/python2.7/site-packages/pymongo/pool.pyc in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation)
#     422         # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#     423         except BaseException as error:
# --> 424             self._raise_connection_failure(error)
#     425
#     426     def send_message(self, message, max_doc_size):
#
# /home/rrs432/miniconda2/envs/bandhub/lib/python2.7/site-packages/pymongo/pool.pyc in _raise_connection_failure(self, error)
#     550             _raise_connection_failure(self.address, error)
#     551         else:
# --> 552             raise error
#     553
#     554     def __eq__(self, other):
#
# AutoReconnect: connection closed

# %%
pointer = postCol.find({'songAccess':{'$exists': True}}, {'songAccess':1 ,'hasRecordedTracks':1, '_id':0})
count = 0
for docs in pointer:
    if(docs['songAccess'] == 1):
        count = count + 1
pprint.pprint(count)
# Out:
# 408353

# %%
myList = []
pointer = trackCol.find({'durationInSeconds':{'$exists': True}}, {'durationInSeconds':1 , '_id':0})
for docs in pointer:
    myList.append(docs['durationInSeconds']) 

#pointer.next


df = pd.DataFrame(myList)
ax = df[(df<1000) & (df >= 0)].plot(kind='hist',grid=True,figsize=(10,10),bins = 1000)
ax.set(xlabel="Duration in seconds", ylabel="Number of mixes")
# Out:
# [Text(0,0.5,u'Number of mixes'), Text(0.5,0,u'Duration in seconds')]

# %%
ytList = []
pointer = trackCol.find({'sourceVideoURL':{'$exists': True}}, {'sourceVideoURL':1 , '_id':0})
#pprint.pprint(pointer)
count = 0
for docs in pointer:
    #pprint.pprint(docs)
    #ytList.append(docs['sourceVideoURL'])
    if docs['sourceVideoURL'] == None:
        ytList.append(0)
    else:
        ytList.append(1)

#pprint.pprint(ytList)

# %%
df = pd.DataFrame(ytList)
ax = df.plot(kind='bar',grid=True,figsize=(10,10),xticks=range(2)).set(ylabel="Number of published tracks", xlabel="0 - Not YouTube, 1 - From YouTube")

# %%
myList = []
pubTracks = postCol.find({'songAccess':{'$exists': True}}, {'participantsInfo':1 ,'songAccess':1, '_id':0})
for docs in pubTracks:
    if(docs['songAccess'] == 1):
        myList.append(len(docs['participantsInfo']['publishedTracks']))
#df = pd.DataFrame(myList)
#ax = df[(df<20) & (df>0)].plot(kind='hist',grid=True,figsize=(10,10),bins=18,xticks=range(20)).set(xlabel="Number of published tracks", ylabel="Number of mixes")

# %%
df = pd.DataFrame(myList)

# %%
ax = df[(df<20) & (df>=0)].plot(kind='hist',grid=True,figsize=(10,10),bins=18,xticks=range(20)).set(xlabel="Number of published tracks", ylabel="Number of mixes")

# %%
pointer = postCol.find()({'collabSettings':{'$exists': True}}, {'collabSettings':1, '_id':0})
for docs in pointer:
    pprint.pprint(docs)
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-52-c118b880973b> in <module>()
# ----> 1 pointer = postCol.find()({'collabSettings':{'$exists': True}}, {'collabSettings':1, '_id':0})
#       2 for docs in pointer:
#       3     pprint.pprint(docs)
#
# TypeError: 'Cursor' object is not callable

# %%
pointer = postCol.find()[5]
for docs in pointer:
    pprint.pprint(docs)
# Out:
# u'owner'
# u'relevantProUsers'
# u'youtubeID'
# u'ownerIsAlive'
# u'mb_artist'
# u'relevantUsers'
# u'numberOfViews'
# u'subTitle'
# u'objectId'
# u'songAccess'
# u'isFeatured'
# u'score'
# u'type'
# u'activities'
# u'dateCreated'
# u'commentsInfo'
# u'hasRecordedTracks'
# u'songInvitedUserIds'
# u'dateLastModified'
# u'title'
# u'participantsInfo'
# u'ownerId'
# u'_id'

# %%
#pointer = songCol.find()[15:16]
genreList = []
genre = songCol.find({'channels':{'$exists': True}}, {'channels':1 , '_id':0})
count = 0
for docs in genre:
    count = count + 1
    if len(docs['channels'])>0:
        genreList.append(docs['channels']) 
pprint.pprint(genreList)
# Out:
# [[u'Pop', u'British'],
#  [u'American', u'ClassicRock'],
#  [u'60s', u'Beatles', u'ClassicRock', u'British'],
#  [u'British', u'Pop', u'90s'],
#  [u'American', u'Pop'],
#  [u'70s', u'British', u'ClassicRock'],
#  [u'RnB', u'American', u'60s'],
#  [u'70s', u'British', u'ClassicRock', u'HardRock'],
#  [u'ClassicRock', u'American', u'70s'],
#  [u'AlternativeRock', u'American', u'90s'],
#  [u'American', u'Pop'],
#  [u'Latin', u'WorldMusic'],
#  [u'Jazz', u'OriginalMusic', u'American'],
#  [u'OriginalMusic', u'RnB'],
#  [u'OriginalMusic', u'British'],
#  [u'Argentinos'],
#  [u'HardRock', u'British'],
#  [u'Indie', u'American'],
#  [u'OriginalMusic'],
#  [u'Suomi', u'Metal', u'British'],
#  [u'OriginalMusic', u'RnB', u'Canadians'],
#  [u'Punk', u'British', u'80s'],
#  [u'American', u'Canadians', u'AlternativeRock'],
#  [u'AlternativeRock', u'Funk', u'American', u'Canadians'],
#  [u'Funk', u'AlternativeRock', u'Canadians', u'American'],
#  [u'RnB', u'American'],
#  [u'AlternativeRock', u'American'],
#  [u'AlternativeRock', u'American'],
#  [u'90s', u'AlternativeRock', u'American'],
#  [u'90s', u'AlternativeRock', u'American'],
#  [u'70s', u'Beatles', u'British', u'ClassicRock'],
#  [u'AlternativeRock', u'Canadians', u'Australians'],
#  [u'Funk', u'AlternativeRock', u'American', u'Canadians'],
#  [u'British', u'Canadians', u'Beatles', u'ClassicRock', u'70s'],
#  [u'80s', u'Canadians', u'British', u'AlternativeRock'],
#  [u'Pop', u'Canadians', u'AlternativeRock', u'American'],
#  [u'American', u'AlternativeRock', u'90s', u'Canadians'],
#  [u'Jazz', u'American'],
#  [u'Pop', u'American'],
#  [u'Punk', u'American'],
#  [u'Country', u'American'],
#  [u'Funk', u'Canadians', u'Fran\xe7ais'],
#  [u'70s', u'British', u'ClassicRock'],
#  [u'Electronic', u'Fran\xe7ais', u'Belgen'],
#  [u'AlternativeRock', u'American'],
#  [u'Christian'],
#  [u'RnB', u'Australians'],
#  [u'Canadians', u'Country', u'Australians'],
#  [u'AlternativeRock', u'British'],
#  [u'Pop', u'American'],
#  [u'British', u'AlternativeRock', u'Fran\xe7ais'],
#  [u'Fran\xe7ais', u'Punk'],
#  [u'American', u'Pop'],
#  [u'Christian', u'American'],
#  [u'Pop', u'British'],
#  [u'American', u'Pop'],
#  [u'Pop', u'British'],
#  [u'AlternativeRock', u'American'],
#  [u'90s', u'AlternativeRock', u'American'],
#  [u'American', u'AlternativeRock', u'Canadians'],
#  [u'Funk', u'70s', u'Canadians', u'American'],
#  [u'Pop', u'American'],
#  [u'90s', u'AlternativeRock', u'Irish'],
#  [u'Punk', u'80s', u'American'],
#  [u'British', u'Pop'],
#  [u'AlternativeRock', u'90s', u'American'],
#  [u'American', u'HardRock', u'70s'],
#  [u'RnB', u'Christian', u'American'],
#  [u'ClassicRock', u'90s', u'British'],
#  [u'80s', u'AlternativeRock', u'American'],
#  [u'American', u'AlternativeRock'],
#  [u'American', u'Pop'],
#  [u'Pop', u'American', u'70s', u'Canadians'],
#  [u'Australians', u'Christian', u'Canadians'],
#  [u'Australians', u'Canadians', u'Christian'],
#  [u'Jazz', u'American'],
#  [u'60s', u'ClassicRock', u'American'],
#  [u'Jazz', u'American'],
#  [u'British', u'Pop'],
#  [u'AlternativeRock', u'Belgen', u'Italians'],
#  [u'British', u'Pop'],
#  [u'British', u'Pop'],
#  [u'90s', u'AlternativeRock'],
#  [u'British', u'Pop'],
#  [u'Pop', u'Jazz', u'American'],
#  [u'Pop', u'Indie', u'Belgen', u'Australians'],
#  [u'AlternativeRock', u'American'],
#  [u'Pop', u'American'],
#  [u'American', u'Pop'],
#  [u'AlternativeRock', u'Canadians'],
#  [u'AlternativeRock', u'Canadians'],
#  [u'AlternativeRock', u'Canadians'],
#  [u'British', u'70s', u'HardRock'],
#  [u'British', u'Pop'],
#  [u'Punk', u'American', u'Canadians'],
#  [u'Canadians', u'AlternativeRock', u'American'],
#  [u'British', u'80s', u'AlternativeRock', u'Canadians'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'Australians', u'90s', u'Pop'],
#  [u'80s', u'ClassicRock'],
#  [u'80s', u'AlternativeRock', u'Irish'],
#  [u'American', u'Pop'],
#  [u'Pop', u'British', u'70s'],
#  [u'AlternativeRock', u'American', u'Canadians'],
#  [u'American', u'Pop'],
#  [u'OriginalMusic', u'American'],
#  [u'OriginalMusic', u'Metal'],
#  [u'British', u'Beatles', u'60s', u'ClassicRock'],
#  [u'Pop', u'Canadians'],
#  [u'Pop', u'American'],
#  [u'WorldMusic', u'Movies'],
#  [u'RnB', u'American'],
#  [u'ClassicRock', u'American'],
#  [u'Canadians', u'OriginalMusic'],
#  [u'AlternativeRock', u'90s', u'British'],
#  [u'American', u'Pop', u'70s'],
#  [u'HipHop', u'Deutschen'],
#  [u'HipHop'],
#  [u'Country', u'American'],
#  [u'AlternativeRock', u'American'],
#  [u'American', u'Jazz'],
#  [u'AlternativeRock', u'American'],
#  [u'ClassicRock', u'70s', u'American'],
#  [u'AlternativeRock', u'American'],
#  [u'Pop', u'American'],
#  [u'RnB', u'American'],
#  [u'British', u'Pop'],
#  [u'AlternativeRock', u'British'],
#  [u'HipHop'],
#  [u'HipHop'],
#  [u'American', u'Country'],
#  [u'Pop', u'British'],
#  [u'HipHop'],
#  [u'HipHop'],
#  [u'HipHop'],
#  [u'American', u'Pop'],
#  [u'British', u'Metal'],
#  [u'Latin', u'Canadians'],
#  [u'RnB', u'WorldMusic'],
#  [u'AlternativeRock', u'Canadians'],
#  [u'Pop', u'80s', u'British'],
#  [u'70s', u'Beatles', u'British', u'ClassicRock'],
#  [u'Pop', u'American'],
#  [u'Canadians', u'OriginalMusic'],
#  [u'AlternativeRock', u'American'],
#  [u'AlternativeRock', u'Canadians'],
#  [u'60s', u'Pop', u'American'],
#  [u'AlternativeRock', u'American'],
#  [u'RnB', u'American'],
#  [u'British', u'Pop'],
#  [u'WorldMusic', u'RnB'],
#  [u'Jazz', u'British'],
#  [u'American', u'Pop'],
#  [u'70s', u'Beatles', u'British'],
#  [u'Jazz'],
#  [u'American', u'Pop'],
#  [u'Movies'],
#  [u'\u65e5\u672c\u4eba', u'Movies'],
#  [u'WorldMusic'],
#  [u'Metal', u'Swiss'],
#  [u'ClassicRock', u'American'],
#  [u'Latin', u'WorldMusic'],
#  [u'Deutschen', u'Metal'],
#  [u'Swiss', u'Metal'],
#  [u'American', u'Pop'],
#  [u'OriginalMusic', u'RnB', u'British'],
#  [u'Pop', u'American'],
#  [u'Pop', u'Canadians'],
#  [u'Pop', u'American'],
#  [u'WorldMusic', u'Deutschen'],
#  [u'British', u'Pop'],
#  [u'British', u'Pop'],
#  [u'Espa\xf1ol', u'WorldMusic'],
#  [u'AlternativeRock', u'American'],
#  [u'OriginalMusic', u'British'],
#  [u'British', u'Pop'],
#  [u'Australians', u'Country', u'Canadians'],
#  [u'Irish', u'AlternativeRock'],
#  [u'American', u'Pop'],
#  [u'AlternativeRock', u'American'],
#  [u'AlternativeRock', u'American', u'90s'],
#  [u'British', u'Pop'],
#  [u'Metal', u'P\u0443\u0441\u0441\u043a\u0438\u0435', u'WorldMusic'],
#  [u'American', u'Pop'],
#  [u'HardRock', u'American'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'60s', u'Beatles', u'ClassicRock'],
#  [u'AlternativeRock'],
#  [u'RnB'],
#  [u'Pop', u'American'],
#  [u'British', u'Pop'],
#  [u'AlternativeRock', u'British'],
#  [u'AlternativeRock', u'Canadians'],
#  [u'British', u'Pop'],
#  [u'90s', u'AlternativeRock', u'American'],
#  [u'American', u'Pop'],
#  [u'Pop', u'80s', u'American'],
#  [u'Pop', u'American'],
#  [u'Svensk', u'WorldMusic'],
#  [u'90s', u'AlternativeRock', u'American'],
#  [u'90s', u'AlternativeRock', u'American'],
#  [u'70s', u'British', u'Beatles', u'ClassicRock'],
#  [u'AlternativeRock', u'American'],
#  [u'Pop', u'80s', u'British'],
#  [u'Jazz', u'American'],
#  [u'Jazz', u'American'],
#  [u'American', u'Pop'],
#  [u'70s', u'Beatles', u'British', u'ClassicRock'],
#  [u'Pop', u'British'],
#  [u'British', u'Pop'],
#  [u'60s', u'British', u'ClassicRock', u'Beatles'],
#  [u'ClassicRock', u'American'],
#  [u'Metal', u'Fran\xe7ais', u'Punk'],
#  [u'Canadians', u'OriginalMusic'],
#  [u'British', u'Pop'],
#  [u'WorldMusic'],
#  [u'British', u'Pop'],
#  [u'OriginalMusic', u'American'],
#  [u'OriginalMusic', u'American'],
#  [u'Pop', u'British'],
#  [u'Jazz', u'American'],
#  [u'80s', u'British', u'ClassicRock'],
#  [u'American', u'Indie'],
#  [u'90s', u'AlternativeRock', u'American'],
#  [u'American', u'Metal'],
#  [u'70s', u'Beatles', u'British', u'ClassicRock'],
#  [u'80s', u'British', u'ClassicRock'],
#  [u'70s', u'British', u'HardRock'],
#  [u'AlternativeRock', u'American'],
#  [u'British', u'Pop'],
#  [u'British', u'ClassicRock', u'70s'],
#  [u'British', u'Pop'],
#  [u'British', u'ClassicRock', u'80s'],
#  [u'American', u'ClassicRock', u'70s'],
#  [u'Jazz', u'American'],
#  [u'AlternativeRock', u'American'],
#  [u'ClassicRock', u'American'],
#  [u'Pop', u'American'],
#  [u'AlternativeRock', u'Irish'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'AlternativeRock', u'American'],
#  [u'British', u'Pop'],
#  [u'Irish', u'80s', u'WorldMusic', u'ClassicRock'],
#  [u'Australians', u'Pop'],
#  [u'Jazz', u'American'],
#  [u'Pop', u'British'],
#  [u'Pop', u'British'],
#  [u'AlternativeRock', u'American'],
#  [u'80s', u'Pop', u'Canadians'],
#  [u'AlternativeRock', u'American'],
#  [u'Jazz', u'American'],
#  [u'Jazz', u'American'],
#  [u'American', u'Jazz'],
#  [u'Pop', u'British'],
#  [u'British', u'Pop'],
#  [u'American', u'AlternativeRock'],
#  [u'American', u'Pop'],
#  [u'American', u'ClassicRock', u'80s'],
#  [u'British', u'Movies', u'90s', u'ClassicRock'],
#  [u'Australians', u'Pop'],
#  [u'British', u'ClassicRock'],
#  [u'Canadians', u'OriginalMusic'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'American', u'Pop'],
#  [u'British', u'AlternativeRock', u'80s'],
#  [u'Metal', u'Canadians'],
#  [u'Metal', u'Hollantilainen', u'British'],
#  [u'70s', u'Beatles', u'British', u'ClassicRock'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'80s', u'AlternativeRock', u'American'],
#  [u'RnB', u'American'],
#  [u'90s', u'AlternativeRock', u'American'],
#  [u'American', u'AlternativeRock'],
#  [u'Brasileiros', u'Argentinos', u'Espa\xf1ol', u'BossaNova'],
#  [u'American', u'Country'],
#  [u'90s', u'AlternativeRock', u'American'],
#  [u'OriginalMusic'],
#  [u'Argentinos', u'Espa\xf1ol'],
#  [u'American', u'Pop'],
#  [u'British', u'Pop'],
#  [u'AlternativeRock', u'American'],
#  [u'British', u'Pop'],
#  [u'Punk', u'American'],
#  [u'90s', u'British', u'Pop'],
#  [u'ClassicRock', u'British', u'70s'],
#  [u'Movies', u'British'],
#  [u'American', u'Country', u'Canadians'],
#  [u'American', u'Pop'],
#  [u'Children', u'American'],
#  [u'British', u'Pop'],
#  [u'British', u'Pop'],
#  [u'Electronic', u'OriginalMusic'],
#  [u'Metal'],
#  [u'RnB', u'American'],
#  [u'American', u'Pop'],
#  [u'80s', u'British', u'ClassicRock'],
#  [u'British', u'Pop'],
#  [u'AlternativeRock', u'American'],
#  [u'American', u'Jazz'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'OriginalMusic'],
#  [u'British', u'WorldMusic'],
#  [u'Svensk', u'WorldMusic'],
#  [u'RnB'],
#  [u'RnB'],
#  [u'Espa\xf1ol', u'Movies'],
#  [u'British', u'Pop'],
#  [u'60s', u'ClassicRock', u'American'],
#  [u'RnB', u'British'],
#  [u'60s', u'Beatles', u'British', u'Canadians', u'ClassicRock'],
#  [u'British', u'Pop'],
#  [u'Espa\xf1ol'],
#  [u'Svensk', u'WorldMusic'],
#  [u'70s', u'HardRock', u'Metal', u'British'],
#  [u'British', u'Pop'],
#  [u'Deutschen', u'HipHop'],
#  [u'Pop', u'British'],
#  [u'90s', u'AlternativeRock'],
#  [u'Canadians', u'OriginalMusic'],
#  [u'80s', u'British', u'ClassicRock'],
#  [u'Australians', u'Canadians', u'Christian'],
#  [u'HardRock', u'American'],
#  [u'American', u'Pop'],
#  [u'ClassicRock', u'70s', u'American'],
#  [u'WorldMusic'],
#  [u'Australians', u'Christian', u'Canadians'],
#  [u'American', u'Pop'],
#  [u'OriginalMusic', u'Chilenos', u'Espa\xf1ol'],
#  [u'British', u'70s', u'HardRock', u'Metal'],
#  [u'American', u'Pop'],
#  [u'Pop', u'American'],
#  [u'Punk', u'American', u'90s'],
#  [u'OriginalMusic'],
#  [u'80s', u'Pop', u'British'],
#  [u'80s', u'American', u'HardRock'],
#  [u'Country', u'British'],
#  [u'Svensk', u'WorldMusic'],
#  [u'British', u'70s', u'ClassicRock'],
#  [u'AlternativeRock', u'American'],
#  [u'Metal', u'Suomi', u'WorldMusic'],
#  [u'American', u'Punk'],
#  [u'RnB', u'American'],
#  [u'60s', u'British', u'ClassicRock'],
#  [u'HardRock', u'American', u'90s', u'Pop'],
#  [u'AlternativeRock', u'American'],
#  [u'Svensk', u'WorldMusic'],
#  [u'Pop', u'American'],
#  [u'HardRock', u'American'],
#  [u'American', u'Pop'],
#  [u'Metal', u'Suomi'],
#  [u'Country'],
#  [u'AlternativeRock', u'American'],
#  [u'AlternativeRock', u'American'],
#  [u'AlternativeRock', u'Irish'],
#  [u'90s', u'AlternativeRock', u'American'],
#  [u'70s', u'ClassicRock', u'American', u'Canadians'],
#  [u'Espa\xf1ol', u'WorldMusic'],
#  [u'Pop', u'American'],
#  [u'60s', u'American', u'ClassicRock'],
#  [u'Argentinos', u'Pop', u'British'],
#  [u'Svensk', u'WorldMusic'],
#  [u'Jazz'],
#  [u'American', u'HardRock'],
#  [u'Irish', u'ClassicRock'],
#  [u'Metal', u'Suomi', u'American'],
#  [u'OriginalMusic'],
#  [u'Pop'],
#  [u'ClassicRock', u'80s', u'British'],
#  [u'Brasileiros', u'BossaNova'],
#  [u'Irish', u'AlternativeRock'],
#  [u'British', u'Pop'],
#  [u'Country', u'American'],
#  [u'WorldMusic', u'British'],
#  [u'80s', u'British', u'ClassicRock'],
#  [u'AlternativeRock', u'American'],
#  [u'British', u'70s', u'Christian'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'AlternativeRock', u'American'],
#  [u'British', u'Pop'],
#  [u'ClassicRock', u'British'],
#  [u'70s', u'American', u'Espa\xf1ol', u'ClassicRock'],
#  [u'Australians', u'Christian'],
#  [u'80s', u'Punk', u'American'],
#  [u'HipHop', u'Pop', u'American'],
#  [u'ClassicRock', u'British'],
#  [u'British', u'Pop'],
#  [u'Pop', u'WorldMusic'],
#  [u'80s', u'British', u'ClassicRock'],
#  [u'ClassicRock'],
#  [u'Canadians', u'American', u'Pop'],
#  [u'British', u'Pop'],
#  [u'American', u'Pop'],
#  [u'Pop'],
#  [u'AlternativeRock', u'American'],
#  [u'Pop', u'Svensk'],
#  [u'Pop'],
#  [u'Argentinos', u'Metal', u'British'],
#  [u'Italians', u'70s', u'British', u'ClassicRock'],
#  [u'90s', u'AlternativeRock', u'American'],
#  [u'Suomi', u'Metal'],
#  [u'60s', u'Beatles', u'Canadians', u'British', u'ClassicRock'],
#  [u'WorldMusic', u'Svensk'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'British', u'70s', u'ClassicRock'],
#  [u'British', u'Pop'],
#  [u'British', u'Pop'],
#  [u'British', u'Pop'],
#  [u'AlternativeRock', u'American'],
#  [u'OriginalMusic'],
#  [u'HipHop'],
#  [u'HipHop'],
#  [u'HipHop', u'Deutschen'],
#  [u'British', u'Pop'],
#  [u'Funk', u'80s', u'American'],
#  [u'ClassicRock', u'British'],
#  [u'AlternativeRock', u'Canadians'],
#  [u'60s', u'American', u'Canadians', u'ClassicRock'],
#  [u'ClassicRock'],
#  [u'HipHop'],
#  [u'HipHop'],
#  [u'Canadians', u'OriginalMusic'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'60s', u'Beatles', u'British', u'Canadians', u'ClassicRock'],
#  [u'AlternativeRock', u'British'],
#  [u'OriginalMusic'],
#  [u'70s', u'American', u'ClassicRock'],
#  [u'80s', u'Australians', u'ClassicRock'],
#  [u'American', u'Chilenos', u'Movies'],
#  [u'British', u'70s', u'HardRock', u'Metal'],
#  [u'Metal', u'WorldMusic', u'P\u0443\u0441\u0441\u043a\u0438\u0435'],
#  [u'90s', u'American', u'Punk'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'AlternativeRock', u'Australians', u'80s'],
#  [u'Australians', u'ClassicRock', u'90s'],
#  [u'AlternativeRock', u'American', u'90s'],
#  [u'70s', u'Beatles', u'British', u'ClassicRock'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'AlternativeRock', u'American'],
#  [u'Pop', u'Svensk'],
#  [u'American', u'Pop'],
#  [u'British', u'Pop'],
#  [u'OriginalMusic', u'Metal', u'Suomi'],
#  [u'OriginalMusic', u'Metal', u'Suomi'],
#  [u'Australians', u'Pop'],
#  [u'American', u'Pop'],
#  [u'British', u'Pop'],
#  [u'Pop', u'American'],
#  [u'Pop', u'Svensk'],
#  [u'AlternativeRock', u'American', u'Canadians'],
#  [u'Canadians', u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'British', u'Pop'],
#  [u'Metal', u'Suomi'],
#  [u'Metal', u'Hollantilainen'],
#  [u'AlternativeRock', u'American'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'OriginalMusic', u'Metal', u'Suomi'],
#  [u'Argentinos', u'HardRock'],
#  [u'70s', u'Beatles', u'British', u'ClassicRock'],
#  [u'AlternativeRock', u'American'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'Canadians', u'British', u'Pop'],
#  [u'AlternativeRock', u'Irish'],
#  [u'American', u'Pop'],
#  [u'British', u'Pop'],
#  [u'RnB'],
#  [u'HardRock', u'80s', u'British', u'Deutschen'],
#  [u'Reggae', u'WorldMusic'],
#  [u'Beatles', u'60s', u'British', u'ClassicRock'],
#  [u'AlternativeRock', u'American', u'90s'],
#  [u'OriginalMusic'],
#  [u'80s', u'AlternativeRock', u'American'],
#  [u'American', u'Pop'],
#  [u'WorldMusic', u'Reggae'],
#  [u'Movies', u'WorldMusic'],
#  [u'British', u'Pop'],
#  [u'Electronic', u'OriginalMusic'],
#  [u'OriginalMusic', u'Chilenos'],
#  [u'British', u'Pop'],
#  [u'OriginalMusic', u'American'],
#  [u'90s', u'AlternativeRock', u'American'],
#  [u'OriginalMusic'],
#  [u'70s', u'British', u'ClassicRock'],
#  [u'Canadians', u'OriginalMusic'],
#  [u'60s', u'Beatles', u'ClassicRock', u'British'],
#  [u'British', u'Pop'],
#  [u'90s', u'AlternativeRock', u'American'],
#  [u'Canadians', u'OriginalMusic'],
#  [u'70s', u'ClassicRock', u'American'],
#  [u'OriginalMusic'],
#  [u'British', u'Pop'],
#  [u'American', u'Pop'],
#  [u'American', u'Pop'],
#  [u'Metal'],
#  [u'Christian', u'American'],
#  [u'OriginalMusic', u'American'],
#  [u'American', u'OriginalMusic'],
#  [u'OriginalMusic', u'American'],
#  [u'OriginalMusic', u'American'],
#  [u'AlternativeRock', u'American'],
#  [u'OriginalMusic'],
#  [u'Metal', u'OriginalMusic'],
#  [u'American', u'Pop'],
#  [u'90s', u'AlternativeRock', u'Irish', u'Espa\xf1ol'],
#  [u'Italians', u'WorldMusic'],
#  [u'Punk', u'American'],
#  [u'American', u'Pop'],
#  [u'WorldMusic', u'Italians'],
#  [u'AlternativeRock', u'American'],
#  [u'OriginalMusic'],
#  [u'Irish', u'WorldMusic'],
#  [u'70s', u'American', u'ClassicRock'],
#  [u'Pop', u'American'],
#  [u'Beatles', u'60s', u'British', u'ClassicRock'],
#  [u'American', u'OriginalMusic'],
#  [u'British', u'Pop'],
#  [u'American', u'Country'],
#  [u'American', u'Indie'],
#  [u'OriginalMusic'],
#  [u'RnB', u'60s', u'American'],
#  [u'American', u'Pop'],
#  [u'American', u'Pop'],
#  [u'90s', u'AlternativeRock', u'American'],
#  [u'OriginalMusic'],
#  [u'Indie', u'British'],
#  [u'Beatles', u'British', u'60s', u'ClassicRock'],
#  [u'60s', u'American', u'ClassicRock'],
#  [u'American', u'Indie'],
#  [u'American', u'Indie'],
#  [u'American', u'Indie'],
#  [u'70s', u'American', u'ClassicRock'],
#  [u'AlternativeRock', u'Fran\xe7ais', u'Belgen'],
#  [u'Country', u'American', u'Movies'],
#  [u'Suomi', u'Metal'],
#  [u'Pop', u'Swiss'],
#  [u'Canadians', u'ClassicRock', u'70s'],
#  [u'Funk', u'OriginalMusic'],
#  [u'AlternativeRock', u'American', u'90s'],
#  [u'Latin', u'WorldMusic', u'Espa\xf1ol'],
#  [u'OriginalMusic'],
#  [u'OriginalMusic'],
#  [u'60s', u'British', u'ClassicRock'],
#  [u'\u65e5\u672c\u4eba', u'Pop'],
#  [u'60s', u'British', u'Beatles', u'Canadians', u'ClassicRock'],
#  [u'Fran\xe7ais', u'Canadians', u'Pop'],
#  [u'American', u'Indie'],
#  [u'Indie', u'Irish'],
#  [u'American', u'OriginalMusic'],
#  [u'OriginalMusic', u'American'],
#  [u'American', u'Pop'],
#  [u'American', u'Indie'],
#  [u'Pop', u'American'],
#  [u'British', u'Pop'],
#  [u'AlternativeRock', u'American'],
#  [u'OriginalMusic'],
#  [u'90s', u'AlternativeRock', u'American'],
#  [u'AlternativeRock', u'American'],
#  [u'60s', u'American', u'ClassicRock'],
#  [u'70s', u'ClassicRock', u'American'],
#  [u'70s', u'Beatles', u'British', u'ClassicRock'],
#  [u'AlternativeRock', u'American'],
#  [u'Irish', u'ClassicRock'],
#  [u'OriginalMusic', u'American'],
#  [u'Canadians', u'OriginalMusic'],
#  [u'American', u'Movies'],
#  [u'American', u'OriginalMusic'],
#  [u'Metal', u'Suomi'],
#  [u'70s', u'American', u'Pop'],
#  [u'Deutschen', u'WorldMusic'],
#  [u'Metal', u'Swiss', u'Deutschen'],
#  [u'American', u'Country', u'Christian'],
#  [u'OriginalMusic'],
#  [u'ClassicRock', u'American', u'British'],
#  [u'AlternativeRock', u'American'],
#  [u'HipHop'],
#  [u'60s', u'British', u'ClassicRock', u'Beatles'],
#  [u'OriginalMusic'],
#  [u'Electronic', u'OriginalMusic'],
#  [u'90s', u'AlternativeRock', u'American'],
#  [u'Espa\xf1ol', u'Mexicanos', u'WorldMusic'],
#  [u'AlternativeRock', u'American'],
#  [u'Canadians', u'OriginalMusic'],
#  [u'60s', u'ClassicRock', u'American'],
#  [u'Canadians', u'Punk'],
#  [u'RnB', u'American', u'60s'],
#  [u'HipHop', u'American'],
#  [u'American', u'Metal'],
#  [u'HipHop', u'American'],
#  [u'American', u'Pop'],
#  [u'American', u'Pop'],
#  [u'British', u'Argentinos', u'Metal'],
#  [u'Pop', u'American', u'British'],
#  [u'American', u'Pop'],
#  [u'American', u'Pop'],
#  [u'Suomi', u'Metal'],
#  [u'British', u'Pop'],
#  [u'AlternativeRock', u'American'],
#  [u'70s', u'British', u'ClassicRock'],
#  [u'Espa\xf1ol', u'WorldMusic'],
#  [u'OriginalMusic'],
#  [u'70s', u'ClassicRock', u'American'],
#  [u'British', u'Pop'],
#  [u'80s', u'Pop', u'Espa\xf1ol', u'British'],
#  [u'British', u'Pop'],
#  [u'WorldMusic', u'Irish'],
#  [u'OriginalMusic', u'British'],
#  [u'American', u'Pop'],
#  [u'American', u'Pop'],
#  [u'OriginalMusic', u'HipHop'],
#  [u'British', u'Pop'],
#  [u'OriginalMusic'],
#  [u'Belgen', u'WorldMusic'],
#  [u'70s', u'Beatles', u'British', u'ClassicRock'],
#  [u'OriginalMusic'],
#  [u'70s', u'Beatles', u'British', u'ClassicRock'],
#  [u'Irish', u'AlternativeRock'],
#  [u'AlternativeRock', u'American'],
#  [u'70s', u'Beatles', u'British', u'ClassicRock'],
#  [u'OriginalMusic', u'Espa\xf1ol'],
#  [u'70s', u'Beatles', u'British', u'ClassicRock'],
#  [u'British', u'Pop'],
#  [u'OriginalMusic'],
#  [u'British', u'Pop'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'Canadians', u'Pop'],
#  [u'OriginalMusic', u'Espa\xf1ol'],
#  [u'British', u'Pop'],
#  [u'80s', u'American'],
#  [u'90s', u'AlternativeRock', u'American'],
#  [u'British', u'Pop'],
#  [u'Country', u'American'],
#  [u'60s', u'British', u'Beatles', u'ClassicRock'],
#  [u'American', u'Canadians', u'HardRock'],
#  [u'ClassicRock', u'70s', u'British'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'Pop', u'American', u'Canadians'],
#  [u'RnB', u'American'],
#  [u'Pop', u'American'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'60s', u'ClassicRock', u'American'],
#  [u'AlternativeRock', u'Irish'],
#  [u'AlternativeRock', u'American'],
#  [u'OriginalMusic'],
#  [u'Punk', u'American', u'Chilenos'],
#  [u'WorldMusic', u'American'],
#  [u'Pop', u'American'],
#  [u'60s', u'ClassicRock', u'British', u'Beatles'],
#  [u'American', u'ClassicRock'],
#  [u'OriginalMusic'],
#  [u'AlternativeRock', u'American'],
#  [u'70s', u'ClassicRock', u'American'],
#  [u'Chilenos', u'Movies'],
#  [u'American', u'Pop'],
#  [u'60s', u'ClassicRock', u'British'],
#  [u'American', u'Country'],
#  [u'Metal', u'Suomi'],
#  [u'70s', u'Beatles', u'British', u'ClassicRock'],
#  [u'OriginalMusic'],
#  [u'AlternativeRock', u'American'],
#  [u'Movies', u'\u65e5\u672c\u4eba'],
#  [u'60s', u'American', u'ClassicRock'],
#  [u'OriginalMusic'],
#  [u'American', u'Pop'],
#  [u'American', u'Pop'],
#  [u'Movies', u'American'],
#  [u'Metal', u'American'],
#  [u'70s', u'Beatles', u'British', u'ClassicRock'],
#  [u'Suomi', u'Metal'],
#  [u'OriginalMusic'],
#  [u'AlternativeRock', u'Irish'],
#  [u'Christian', u'American'],
#  [u'American', u'British', u'RnB'],
#  [u'American', u'ClassicRock', u'60s', u'Canadians'],
#  [u'Indie', u'American'],
#  [u'RnB', u'90s', u'American', u'Movies'],
#  [u'80s', u'AlternativeRock', u'American'],
#  [u'OriginalMusic'],
#  [u'70s', u'American', u'ClassicRock'],
#  [u'60s', u'British', u'ClassicRock', u'Beatles'],
#  [u'AlternativeRock', u'American'],
#  [u'Beatles', u'70s', u'British', u'ClassicRock'],
#  [u'American', u'Movies'],
#  [u'Metal', u'Irish'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'70s', u'Beatles', u'British', u'ClassicRock'],
#  [u'American', u'Pop'],
#  [u'Irish', u'Movies'],
#  [u'70s', u'Beatles', u'British', u'ClassicRock'],
#  [u'OriginalMusic'],
#  [u'Pop', u'80s', u'American'],
#  [u'70s', u'Espa\xf1ol', u'Beatles', u'British', u'ClassicRock'],
#  [u'Metal', u'Suomi', u'Svensk'],
#  [u'Deutschen', u'Metal'],
#  [u'Deutschen', u'Movies', u'Pop'],
#  [u'WorldMusic', u'Movies'],
#  [u'Movies'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'British', u'Pop'],
#  [u'Movies', u'American'],
#  [u'OriginalMusic'],
#  [u'OriginalMusic', u'Pop', u'American'],
#  [u'American', u'Pop', u'OriginalMusic'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'OriginalMusic', u'Pop', u'American'],
#  [u'American', u'OriginalMusic'],
#  [u'American', u'ClassicRock', u'British', u'60s'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'Canadians', u'OriginalMusic'],
#  [u'Australians', u'Christian'],
#  [u'Country', u'American'],
#  [u'OriginalMusic'],
#  [u'AlternativeRock', u'90s', u'American'],
#  [u'70s', u'Beatles', u'British', u'ClassicRock'],
#  [u'Pop', u'American'],
#  [u'AlternativeRock', u'American'],
#  [u'70s', u'Beatles', u'British', u'ClassicRock'],
#  [u'Country', u'American'],
#  [u'OriginalMusic'],
#  [u'70s', u'British', u'ClassicRock', u'Beatles'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'American', u'OriginalMusic'],
#  [u'Pop', u'American'],
#  [u'Espa\xf1ol', u'AlternativeRock', u'Irish'],
#  [u'60s', u'British', u'Beatles', u'ClassicRock'],
#  [u'AlternativeRock', u'British'],
#  [u'Irish', u'British', u'WorldMusic'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'American', u'Pop'],
#  [u'60s', u'British', u'Beatles', u'ClassicRock'],
#  [u'60s', u'British', u'ClassicRock', u'Beatles'],
#  [u'American', u'Pop'],
#  [u'90s', u'AlternativeRock', u'American'],
#  [u'British', u'AlternativeRock'],
#  [u'Deutschen', u'Metal'],
#  [u'Metal', u'Deutschen'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'RnB', u'American'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'OriginalMusic'],
#  [u'Country', u'American'],
#  [u'American', u'Pop'],
#  [u'AlternativeRock', u'American'],
#  [u'60s', u'British', u'ClassicRock', u'Beatles'],
#  [u'OriginalMusic', u'American'],
#  [u'60s', u'British', u'ClassicRock', u'Beatles'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'70s', u'Beatles', u'ClassicRock', u'British'],
#  [u'Argentinos', u'Latin'],
#  [u'60s', u'British', u'Beatles', u'ClassicRock'],
#  [u'80s', u'AlternativeRock', u'American'],
#  [u'90s', u'AlternativeRock', u'American'],
#  [u'RnB', u'American', u'British', u'Jazz'],
#  [u'OriginalMusic'],
#  [u'AlternativeRock', u'Irish'],
#  [u'OriginalMusic'],
#  [u'Indie', u'American'],
#  [u'OriginalMusic'],
#  [u'80s', u'AlternativeRock', u'American'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'80s', u'AlternativeRock', u'American'],
#  [u'Deutschen', u'Pop'],
#  [u'70s', u'British', u'Beatles', u'ClassicRock'],
#  [u'Pop', u'Svensk'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'OriginalMusic'],
#  [u'American', u'70s', u'Christian'],
#  [u'British', u'Pop'],
#  [u'British', u'Pop'],
#  [u'WorldMusic'],
#  [u'OriginalMusic'],
#  [u'70s', u'ClassicRock', u'British'],
#  [u'RnB', u'American', u'British'],
#  [u'British'],
#  [u'60s', u'Beatles', u'ClassicRock', u'British'],
#  [u'OriginalMusic'],
#  [u'AlternativeRock', u'British'],
#  [u'90s', u'AlternativeRock', u'American'],
#  [u'Pop', u'American'],
#  [u'AlternativeRock', u'British'],
#  [u'80s', u'American', u'AlternativeRock'],
#  [u'90s', u'AlternativeRock', u'American'],
#  [u'OriginalMusic'],
#  [u'British', u'Pop'],
#  [u'Espa\xf1ol', u'WorldMusic', u'Mexicanos'],
#  [u'Espa\xf1ol', u'WorldMusic', u'Mexicanos'],
#  [u'American', u'Pop'],
#  [u'Espa\xf1ol', u'WorldMusic', u'Mexicanos'],
#  [u'OriginalMusic'],
#  [u'British', u'Pop'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'American', u'Pop'],
#  [u'60s', u'British', u'Beatles', u'ClassicRock'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'American', u'Pop'],
#  [u'Metal', u'OriginalMusic'],
#  [u'AlternativeRock', u'American'],
#  [u'OriginalMusic'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'OriginalMusic'],
#  [u'OriginalMusic', u'Metal'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'American', u'AlternativeRock'],
#  [u'60s', u'British', u'ClassicRock', u'Beatles'],
#  [u'American', u'Pop'],
#  [u'AlternativeRock', u'American'],
#  [u'British', u'Pop'],
#  [u'British', u'Pop'],
#  [u'OriginalMusic'],
#  [u'Pop', u'British'],
#  [u'60s', u'British', u'Beatles', u'ClassicRock'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'British', u'Pop'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'British', u'Pop'],
#  [u'British', u'Pop'],
#  [u'60s', u'Beatles', u'British', u'ClassicRock'],
#  [u'Espa\xf1ol', u'WorldMusic'],
#  [u'OriginalMusic'],
#  [u'OriginalMusic'],
#  [u'AlternativeRock', u'American'],
#  [u'OriginalMusic'],
#  [u'OriginalMusic'],
#  [u'OriginalMusic'],
#  [u'OriginalMusic'],
#  [u'OriginalMusic'],
#  [u'OriginalMusic'],
#  [u'OriginalMusic'],
#  [u'American', u'Pop'],
#  [u'OriginalMusic'],
#  [u'OriginalMusic'],
#  [u'American', u'Pop'],
#  [u'British', u'Pop'],
#  [u'British', u'Pop'],
#  [u'AlternativeRock', u'American'],
#  [u'British', u'Pop'],
#  [u'American', u'Pop'],
#  [u'British', u'Pop'],
#  [u'Pop', u'British'],
#  [u'American', u'Pop'],
#  [u'British', u'Pop'],
#  [u'British', u'Pop'],
#  [u'British', u'Pop'],
#  [u'British', u'Pop']]

# %%
#pointer = songCol.find()[15:16]
genre_set = set()
for g in genreList:
    for _g in g:
        genre_set.add(_g)

# %%
len(genre_set)
# Out:
# 46

# %%
genre.count()
# Out:
# 1199

# %%
cursor = trackCol.find({'instrumentAssignedBySongOwner' : {'$exists' : True}})
myList = []
for doc in cursor:
    myList.append(doc['instrumentAssignedBySongOwner'])

# %%
len(set(myList))
# Out:
# 23

# %%
instrument_set = list(set(myList))

# %%
sorted(zip(instrument_set, np.bincount([instrument_set.index(i) for i in myList])), key=lambda x:-x[1])
# Out:
# [(u'lead-vocals', 450),
#  (u'rhythm-guitar', 358),
#  (u'bass', 316),
#  (u'lead-guitar', 276),
#  (u'backing-vocals', 234),
#  (u'drums', 228),
#  (u'keys-piano', 143),
#  (u'percussion', 133),
#  (u'mixing', 35),
#  (u'synth-effects', 24),
#  (u'sax', 20),
#  (u'trumpet', 12),
#  (u'harmonica', 9),
#  (u'flute', 8),
#  (u'harp', 6),
#  (u'ukulele', 4),
#  (u'turntable', 3),
#  (u'violin', 2),
#  (u'clarinet', 2),
#  (u'banjo', 2),
#  (u'cello', 2),
#  (u'accordion', 1),
#  (u'pedal-steel-guitar', 1)]

# %%
cursor = trackCol.find({'durationInSeconds':{'$exists': True}}, {'durationInSeconds':1 , '_id':0})
for doc in cursor[1:10]:
    pprint.pprint(doc)
# Out:
# {u'durationInSeconds': 175.5675354003906}
# {u'durationInSeconds': 215.087890625}
# {u'durationInSeconds': 9.707391738891602}
# {u'durationInSeconds': 9.150113105773926}
# {u'durationInSeconds': 9.126893043518066}
# {u'durationInSeconds': 190.9159240722656}
# {u'durationInSeconds': 8.825034141540527}
# {u'durationInSeconds': 138.3227233886719}
# {u'durationInSeconds': 127.3164596557617}

# %%
pointer = trackCol.find({'durationInSeconds':{'$exists': True}}, {'durationInSeconds':1 , '_id':0})
for docs in
